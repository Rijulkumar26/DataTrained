# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## EDA:

# %%
df = pd.read_csv('baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#Statistical summary
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# #### We have 30 data rows and 12 columns in the dataframe.

# %%
#Column Data type
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### Point to note here is that all columns are numeric

# %% [markdown]
# ### Checking Null values:

# %%
#Checking null values using heatmap
sns.heatmap(df.isnull())
plt.show()

# %%
#Total number of null values in complete dataset
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### As we can see no NULL values in whole dataframe

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# #### No null values in any column of dataframe

# %% [markdown]
# ### Density Plots:

# %%
#Making dataframe of Continous data
df_visualisation_continous = df[['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']].copy()

# %%
#Density curves of Continous data
df_visualisation_continous.plot(kind='density',subplots=True,figsize=(16,20))
plt.show()

# %% [markdown]
# #### From above plots we can say that we need to look more carefully for the following column headings: R, H, SO, RA, CG, SHO, SV, E

# %%
#Visualisation of R data
sns.distplot(df_visualisation_continous['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# **We need to check for skewness as slight dual nodes**

# %%
#Visualisation of H data
sns.distplot(df_visualisation_continous['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because of dual nodes**

# %%
#Visualisation of SO data
sns.distplot(df_visualisation_continous['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed a little bit**

# %%
#Visualisation of RA data
sns.distplot(df_visualisation_continous['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed a little bit**

# %%
#Visualisation of CG data
sns.distplot(df_visualisation_continous['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks like it is not normalised**

# %%
#Visualisation of SHO data
sns.distplot(df_visualisation_continous['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because there is a bulge on the right side**

# %%
#Visualisation of SV data
sns.distplot(df_visualisation_continous['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks a bit skewed**

# %%
#Visualisation of E data
sns.distplot(df_visualisation_continous['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it has dual nodes**

# %% [markdown]
# ### Pairplot for the dataframe:

# %%
sns.pairplot(df,height=1.5)

# %% [markdown]
# #### Here we can see pairplot for the whole dataframe

# %% [markdown]
# #### Visualisation is completed

# %% [markdown]
# ### No use of Encoding of Dataframe(Converting String to numeric) in this case because already all are numeric

# %% [markdown]
# ### Correlations:

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df.describe(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Correlation matrix
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#Correlation of Columns with target column using heatmap
plt.figure(figsize = (22,7))
sns.heatmap(df.corr(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here ER, RA, ERA, W columns looks highly dependent on each other

# %%
#Checking columns which appear to be highly correlated with target columns

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Column with target names',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# #### Here also ER, RA, ERA columns looks highly dependent on W

# %%
#Checking correlation between ER and W
plt.figure(figsize=(22,7))
plt.scatter(df.ER,df.W)
plt.show()

# %% [markdown]
# #### Good correlation but not too high

# %%
#Checking correlation between RA and W
plt.figure(figsize=(22,7))
plt.scatter(df.RA,df.W)
plt.show()

# %% [markdown]
# #### Good correlation but not too high

# %%
#Checking correlation between ERA and W
plt.figure(figsize=(22,7))
plt.scatter(df.ERA,df.W)
plt.show()

# %% [markdown]
# #### Good correlation but not too high

# %%
#Checking correlation between ER and RA
plt.figure(figsize=(22,7))
plt.scatter(df.ER,df.RA)
plt.show()

# %% [markdown]
# #### As we can see clearly ER and RA have high positive correlation

# %%
#Checking correlation between ERA and ER
plt.figure(figsize=(22,7))
plt.scatter(df.ERA,df.ER)
plt.show()

# %% [markdown]
# #### As we can see clearly ERA and ER have high positive correlation

# %%
#Checking correlation between ERA and RA
plt.figure(figsize=(22,7))
plt.scatter(df.ERA,df.RA)
plt.show()

# %% [markdown]
# #### As we can see clearly ERA and RA have high positive correlation

# %% [markdown]
# #### So finally we can say that ERA, ER and RA have high positive correlations

# %% [markdown]
# ### Checkin VIF for confirmation of above conclusion:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X = df[['ER', 'ERA', 'RA','W']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

# %%
print(vif_dF)
# Out:
#   feature           VIF
# 0      ER  24779.251919
# 1     ERA  16033.011845
# 2      RA   5172.186418
# 3       W     28.783789

# %% [markdown]
# ### As we can see ER,ERA and RA are highly correlated

# %% [markdown]
# ### Hence dropping ER and ERA :

# %%
#We need to drop TV as it is highly correlated to target data and also has dual nodes in distribution plot
df = df.drop("ER", axis=1)
df = df.drop("ERA", axis=1)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104  641   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70  700   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68  701   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83  803   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88  670   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63  698   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44  693   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87  642   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71  753   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101  733   5    9  45  119
# ...

# %% [markdown]
# ### Removing Skewness :

# %%
#Checking skewness
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# #### Acceptable skewness (-0.65,+0.65)

# %%
#Applying yeo-johnson
from scipy.stats import yeojohnson
df.R = yeojohnson(df.R)[0]
df.H = yeojohnson(df.H)[0]
df.CG = yeojohnson(df.CG)[0]
df.SV = yeojohnson(df.SV)[0]
df.E = yeojohnson(df.E)[0]

# %%
df.skew()
# Out:
# W      0.047089
# R      0.000000
# AB     0.183437
# H      0.000000
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# CG    -0.059785
# SHO    0.565790
# SV     0.000836
# E      0.000000
# dtype: float64

# %% [markdown]
# ### Removing outliers :

# %%
#Outlier check
df.dtypes
# Out:
# W        int64
# R      float64
# AB       int64
# H      float64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# CG     float64
# SHO      int64
# SV     float64
# E      float64
# dtype: object

# %%
#Radio and newspaper are the only continous data types left
df.plot.box(layout =(6,4),subplots=True,figsize=(16,20))
# Out:
# W         AxesSubplot(0.125,0.772143;0.168478x0.107857)
# R      AxesSubplot(0.327174,0.772143;0.168478x0.107857)
# AB     AxesSubplot(0.529348,0.772143;0.168478x0.107857)
# H      AxesSubplot(0.731522,0.772143;0.168478x0.107857)
# 2B        AxesSubplot(0.125,0.642714;0.168478x0.107857)
# 3B     AxesSubplot(0.327174,0.642714;0.168478x0.107857)
# HR     AxesSubplot(0.529348,0.642714;0.168478x0.107857)
# BB     AxesSubplot(0.731522,0.642714;0.168478x0.107857)
# SO        AxesSubplot(0.125,0.513286;0.168478x0.107857)
# SB     AxesSubplot(0.327174,0.513286;0.168478x0.107857)
# RA     AxesSubplot(0.529348,0.513286;0.168478x0.107857)
# CG     AxesSubplot(0.731522,0.513286;0.168478x0.107857)
# SHO       AxesSubplot(0.125,0.383857;0.168478x0.107857)
# SV     AxesSubplot(0.327174,0.383857;0.168478x0.107857)
# E      AxesSubplot(0.529348,0.383857;0.168478x0.107857)
# dtype: object

# %% [markdown]
# ### There looks like a outlier in SHO and E columns so now we check with z-score:

# %%
#Outlier removal using z-score
df.shape
# Out:
# (30, 15)

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
threshhold = 3
np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# #### As we can see there are no outliers

# %% [markdown]
# ## Separating the columns into features and target:

# %%
feature = df.drop("W",axis=1)
target = df["W"]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()


from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(r2_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(r2_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.8876046539427654
# At random state 0 the testing accuracy is : 0.33613519453656915
#
#
# At random state 1 the training accuracy is : 0.9251968615459638
# At random state 1 the testing accuracy is : 0.3322770156337601
#
#
# At random state 2 the training accuracy is : 0.933695273315445
# At random state 2 the testing accuracy is : -0.6867883542770308
#
#
# At random state 3 the training accuracy is : 0.9184494437964025
# At random state 3 the testing accuracy is : -0.014748675806727674
#
#
# At random state 4 the training accuracy is : 0.8360006599742176
# At random state 4 the testing accuracy is : 0.8645820308836671
#
#
# At random state 5 the training accuracy is : 0.8598046642477053
# At random state 5 the testing accuracy is : 0.691876939141306
#
#
# At random state 6 the training accuracy is : 0.8771834040395171
# At random state 6 the testing accuracy is : 0.4217463696095328
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = 4)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.8645820308836671

# %% [markdown]
# ### Cross Validation of model:

# %%
Train_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature,target,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is -3.967726482156617 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 3 the cv score is 0.23053232001297097 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 4 the cv score is 0.4817938184097107 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 5 the cv score is -0.22209877006532225 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 6 the cv score is -0.01857295923639955 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 7 the cv score is -0.020368285235858857 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Wins')
plt.ylabel('Predicted Wins')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# As we can see in the graph the prediction wins roughly lies on best fit curve

# %% [markdown]
# ### Trying other models:

# %%
def model_selection(algorithm_instance,features_train,target_train,features_test,target_test):
    algorithm_instance.fit(features_train,target_train)
    model_1_pred_train = algorithm_instance.predict(features_train)
    model_1_pred_test = algorithm_instance.predict(features_test)
    print("Accuracy for the training model : ",r2_score(target_train,model_1_pred_train))
    print("Accuracy for the testing model : ",r2_score(target_test,model_1_pred_test))

# %%
import xgboost as xgb
model_selection(xgb.XGBRegressor(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.9999999974879205
# Accuracy for the testing model :  0.24312011956252277

# %%
from sklearn.ensemble import RandomForestRegressor
model_selection(RandomForestRegressor(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.9111022074756229
# Accuracy for the testing model :  0.5282761290322584

# %%
from sklearn.svm import SVR
model_selection(SVR(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.0006482632182029935
# Accuracy for the testing model :  -0.9871931340853242

# %% [markdown]
# ### Conclusion: Here RandomForestRegressor() gives best accuracy hence taking it as main model

# %% [markdown]
# ### Cross Validation of RandomForestRegressor() model:

# %%
Train_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(RandomForestRegressor(),feature,target,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is -0.434906077859158 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 3 the cv score is 0.26087960164914764 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 4 the cv score is 0.3998081717126657 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 5 the cv score is -0.9735876383764989 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 6 the cv score is 0.09498436077584839 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# At cross fold 7 the cv score is -0.08268470220873485 and accuracy score for training is -0.9377060990008097 and accuracy score for testing is 0.8645820308836671
#
#
# ...

# %% [markdown]
# #### Below we have tested mean squared error, Root mean squared error and Mean Absolute error method also:

# %%
# Mean Squared Error Method
x = RandomForestRegressor()
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_squared_error(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_squared_error(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 7.002595833333337
# At random state 0 the testing accuracy is : 60.302916666666704
#
#
# At random state 1 the training accuracy is : 7.3893666666666675
# At random state 1 the testing accuracy is : 58.19970000000001
#
#
# At random state 2 the training accuracy is : 7.565737499999994
# At random state 2 the testing accuracy is : 72.4273
#
#
# At random state 3 the training accuracy is : 7.302645833333327
# At random state 3 the testing accuracy is : 73.20033333333329
#
#
# At random state 4 the training accuracy is : 9.684762500000003
# At random state 4 the testing accuracy is : 36.05873333333335
#
#
# At random state 5 the training accuracy is : 7.827441666666659
# At random state 5 the testing accuracy is : 46.795133333333325
#
#
# At random state 6 the training accuracy is : 8.609741666666661
# At random state 6 the testing accuracy is : 59.94000000000002
#
#
# At random state 7 the training accuracy is : 6.723191666666669
# ...

# %%
# Root Mean Squared Error Method

for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_squared_error(target_train,pred_train,squared=False)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_squared_error(target_test,pred_test,squared=False)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 2.9329557048592925
# At random state 0 the testing accuracy is : 6.961790957313596
#
#
# At random state 1 the training accuracy is : 2.8869765037723014
# At random state 1 the testing accuracy is : 7.563273100979493
#
#
# At random state 2 the training accuracy is : 2.673390481517181
# At random state 2 the testing accuracy is : 8.749247586697575
#
#
# At random state 3 the training accuracy is : 2.665544034526536
# At random state 3 the testing accuracy is : 8.875484963275717
#
#
# At random state 4 the training accuracy is : 3.257803452225645
# At random state 4 the testing accuracy is : 5.413110627602826
#
#
# At random state 5 the training accuracy is : 2.934859451489968
# At random state 5 the testing accuracy is : 6.799008506147548
#
#
# At random state 6 the training accuracy is : 2.8393191672183193
# At random state 6 the testing accuracy is : 7.470256577476664
#
#
# At random state 7 the training accuracy is : 2.835904470652469
# ...

# %%
# Mean Absolute Error Method

for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_absolute_error(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_absolute_error(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 2.3237499999999986
# At random state 0 the testing accuracy is : 6.008333333333333
#
#
# At random state 1 the training accuracy is : 2.306666666666666
# At random state 1 the testing accuracy is : 6.456666666666666
#
#
# At random state 2 the training accuracy is : 2.185
# At random state 2 the testing accuracy is : 8.061666666666666
#
#
# At random state 3 the training accuracy is : 2.1129166666666674
# At random state 3 the testing accuracy is : 7.885000000000001
#
#
# At random state 4 the training accuracy is : 2.6062500000000006
# At random state 4 the testing accuracy is : 3.0133333333333354
#
#
# At random state 5 the training accuracy is : 2.4545833333333333
# At random state 5 the testing accuracy is : 6.071666666666663
#
#
# At random state 6 the training accuracy is : 2.4258333333333333
# At random state 6 the testing accuracy is : 6.176666666666669
#
#
# At random state 7 the training accuracy is : 2.130833333333334
# ...

# %% [markdown]
# #### Conclusion of 3 metrics method : As we can see we got best accuracy reseults in r2_score among (r2_score, mse, rms)

# %% [markdown]
# ### Regularization using Lasso:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls = Lasso(alpha = 10, random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.8458079122660563

# %%
cv_score = cross_val_score(ls,feature,target,cv=6)
cv_mean =cv_score.mean()
abs(cv_mean)
# Out:
# 0.4310214019493765

# %% [markdown]
# ### Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

#using 4 parameters
parameters = {'criterion':['mse','mae'], 'max_features': ["auto","sqrt","log2"], 'min_samples_split' : [2,5,10], 'min_samples_leaf' : [1,2,4]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
rf = RandomForestRegressor(criterion = "mae", max_features = "auto", min_samples_leaf = 1, min_samples_split = 5)
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 score: ', abs(rfs)*100)

rfscore = cross_val_score(ls,feature,target,cv=6)
rfc =rfscore.mean()
rfc
print('Cross Validation score: ', abs(rfc)*100)
# Out:
# R2 score:  25.55792352156516
# Cross Validation score:  43.10214019493765

# %% [markdown]
# #### Conclusion : Reason why we are getting so low scores are due to lack of sufficient data
