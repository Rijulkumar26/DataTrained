# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## EDA:

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#Statistical summary
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### We have 1470 data rows and 35 columns in the dataframe.

# %%
#Column Data type
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### Point to note here is that all columns are not numeric

# %% [markdown]
# ### Checking Null values:

# %%
#Checking null values using heatmap
sns.heatmap(df.isnull())
plt.show()

# %%
#Total number of null values in complete dataset
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### As we can see no NULL values in whole dataframe

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #### No null values in any column of dataframe

# %% [markdown]
# ### Histogram Plots :

# %%
#Making dataframe of nominal data
df_visualisation_nominal = df[['Education','Attrition','BusinessTravel','Department','EducationField','EnvironmentSatisfaction','Gender','JobInvolvement','JobRole','JobSatisfaction','MaritalStatus','NumCompaniesWorked','Over18','OverTime','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TrainingTimesLastYear','WorkLifeBalance']].copy()

# %%
#Visualisation of Education data
ax = sns.countplot(x='Education',data=df_visualisation_nominal)
print(df_visualisation_nominal['Education'].value_counts())
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %% [markdown]
# **Most employee give their education 3 rating, then 4, them 2, then 1 and finally 5**

# %%
#Visualisation of Attrition data
ax = sns.countplot(x='Attrition',data=df_visualisation_nominal)
print(df_visualisation_nominal['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# **Here we can see imbalance of attrition (target column) ehich we have to oversample**

# %%
#Visualisation of BusinessTravel data
ax = sns.countplot(x='BusinessTravel',data=df_visualisation_nominal)
print(df_visualisation_nominal['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# **Most employee travel rarely, and least are non-travellers**

# %%
#Visualisation of Department data
ax = sns.countplot(x='Department',data=df_visualisation_nominal)
print(df_visualisation_nominal['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# **Most employee are in R&D department, then in Sales and least in Human resources**

# %%
#Visualisation of EducationField data
sns.set(rc={'figure.figsize':(12,4)})
ax = sns.countplot(x='EducationField',data=df_visualisation_nominal)
print(df_visualisation_nominal['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# **Most employee are educated in life sciences, then in Medical, and so on**

# %%
#Visualisation of EnvironmentSatisfaction data
sns.set(rc={'figure.figsize':(6,4)})
ax = sns.countplot(x='EnvironmentSatisfaction',data=df_visualisation_nominal)
print(df_visualisation_nominal['EnvironmentSatisfaction'].value_counts())
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %% [markdown]
# **Most employee gives are satisfied with their working environment**

# %%
#Visualisation of Gender data
ax = sns.countplot(x='Gender',data=df_visualisation_nominal)
print(df_visualisation_nominal['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# **Most employee are male but number of female employees are also around 2/3rd of number of male employees**

# %%
#Visualisation of JobInvolvement data
ax = sns.countplot(x='JobInvolvement',data=df_visualisation_nominal)
print(df_visualisation_nominal['JobInvolvement'].value_counts())
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %% [markdown]
# **Most give there involvement in job as 3 stars, then 2 stars, the 4 and finally 1 star**

# %%
#Visualisation of JobRole data
sns.set(rc={'figure.figsize':(20,4)})
ax = sns.countplot(x='JobRole',data=df_visualisation_nominal)
print(df_visualisation_nominal['JobRole'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# **Most employee are Sales Executives, then research scientists, and so on**

# %%
#Visualisation of JobSatisfaction data
sns.set(rc={'figure.figsize':(6,4)})
ax = sns.countplot(x='JobSatisfaction',data=df_visualisation_nominal)
print(df_visualisation_nominal['JobSatisfaction'].value_counts())
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %% [markdown]
# **Most employees are satisfied with their current job as most gave 4 ratings, then 3, then 1 and finally 2**

# %%
#Visualisation of MaritalStatus data
ax = sns.countplot(x='MaritalStatus',data=df_visualisation_nominal)
print(df_visualisation_nominal['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# **Most employee are married, many are single and least are divorced**

# %%
#Visualisation of NumCompaniesWorked data
ax = sns.countplot(x='NumCompaniesWorked',data=df_visualisation_nominal)
print(df_visualisation_nominal['NumCompaniesWorked'].value_counts())
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %% [markdown]
# **Most employees worked for 1 company**

# %%
#Visualisation of Over18 data
ax = sns.countplot(x='Over18',data=df_visualisation_nominal)
print(df_visualisation_nominal['Over18'].value_counts())
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# **All employees are above 18 years**

# %%
#Visualisation of OverTime data
ax = sns.countplot(x='OverTime',data=df_visualisation_nominal)
print(df_visualisation_nominal['OverTime'].value_counts())
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# **Most employee do overtime as we can see above**

# %%
#Visualisation of PerformanceRating data
ax = sns.countplot(x='PerformanceRating',data=df_visualisation_nominal)
print(df_visualisation_nominal['PerformanceRating'].value_counts())
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# **Most employee have performance rating of 3 and some have rating of 4**

# %%
#Visualisation of RelationshipSatisfaction data
ax = sns.countplot(x='RelationshipSatisfaction',data=df_visualisation_nominal)
print(df_visualisation_nominal['RelationshipSatisfaction'].value_counts())
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %% [markdown]
# **Most employee gives their RelationSatisfaction 3 ratings, then 4 ratings, then 2 ratings and at the end 1 rating this shows that although more are satisfied with their relationship many are still unsatisfied**

# %%
#Visualisation of StandardHours data
ax = sns.countplot(x='StandardHours',data=df_visualisation_nominal)
print(df_visualisation_nominal['StandardHours'].value_counts())
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %% [markdown]
# **As we can see that all (1470) employees work 80 standard hours**

# %%
#Visualisation of StockOptionLevel data
ax = sns.countplot(x='StockOptionLevel',data=df_visualisation_nominal)
print(df_visualisation_nominal['StockOptionLevel'].value_counts())
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %% [markdown]
# **Most employee are Stockoption level 0, then level 1 , then level 2 and finally level 3**

# %%
#Visualisation of TrainingTimesLastYear data
ax = sns.countplot(x='TrainingTimesLastYear',data=df_visualisation_nominal)
print(df_visualisation_nominal['TrainingTimesLastYear'].value_counts())
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64

# %% [markdown]
# **Most employee got Training 2 times, then 3 times, then 4 time, then 5 times, then 1, then 6 and finally 0 times since last year**

# %%
#Visualisation of WorkLifeBalance data
ax = sns.countplot(x='WorkLifeBalance',data=df_visualisation_nominal)
print(df_visualisation_nominal['WorkLifeBalance'].value_counts())
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %% [markdown]
# **Most employee gives WorkLifeBalance 3 ratings (893), then 2 ratings (344), then 4 ratings (153) and at the end 4 rating (80)**

# %% [markdown]
# ### Density Plots:

# %%
#Making dataframe of Continous data
df_visualisation_continous = df[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']].copy()

# %%
#Visualisation of Age data
sns.distplot(df_visualisation_continous['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# **It looks very slightly skewed**

# %%
#Visualisation of DailyRate data
sns.distplot(df_visualisation_continous['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because is not normalised**

# %%
#Visualisation of DistanceFromHome data
sns.distplot(df_visualisation_continous['DistanceFromHome'])
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it is skewed**

# %%
#Visualisation of HourlyRate data
sns.distplot(df_visualisation_continous['HourlyRate'])
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it is not normalised**

# %%
#Visualisation of MonthlyIncome data
sns.distplot(df_visualisation_continous['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it is skewed**

# %%
#Visualisation of MonthlyRate data
sns.distplot(df_visualisation_continous['MonthlyRate'])
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it is not normalised**

# %%
#Visualisation of PercentSalaryHike data
sns.distplot(df_visualisation_continous['PercentSalaryHike'])
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed**

# %%
#Visualisation of TotalWorkingYears data
sns.distplot(df_visualisation_continous['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed**

# %%
#Visualisation of YearsAtCompany data
sns.distplot(df_visualisation_continous['YearsAtCompany'])
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed**

# %%
#Visualisation of YearsInCurrentRole data
sns.distplot(df_visualisation_continous['YearsInCurrentRole'])
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it has dual nodes**

# %%
#Visualisation of YearsSinceLastPromotion data
sns.distplot(df_visualisation_continous['YearsSinceLastPromotion'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it looks skewed**

# %%
#Visualisation of YearsWithCurrManager data
sns.distplot(df_visualisation_continous['YearsWithCurrManager'])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Density'>

# %% [markdown]
# **We need to check skewness because it has dual nodes**

# %% [markdown]
# ### Pairplot for the continous data columns dataframe:

# %%
sns.pairplot(df_visualisation_continous,height=1.5)

# %% [markdown]
# #### Here we can see pairplot for the continous data columns dataframe

# %% [markdown]
# #### Visualisation is completed

# %% [markdown]
# ### Encoding of Dataframe(Converting String to numeric):

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %% [markdown]
# ### Dropping Columns:

# %%
#Dropping column StandardHours as it's value is constant (= 80) for all cases as we have seen in count plot previously
df = df.drop("StandardHours",axis=1)

# %%
#Dropping column Over18 as it's value is always 'yes' for all cases as we have seen in count plot previously
df = df.drop("Over18",axis=1)

# %%
#Dropping column EmployeeCount as it's value is constant (=1) for all cases as we have seen previously
df = df.drop("EmployeeCount",axis=1)

# %% [markdown]
# ### Correlations:

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df.describe(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Correlation matrix
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# ...

# %%
#Correlation of Columns with target column using heatmap
plt.figure(figsize = (25,25))
sns.heatmap(df.corr(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here TotalWorkingYears, JobLevel, MonthlyIncome, Age columns looks highly dependent on each other

# %%
#Checking columns which appear to be highly correlated with target columns

# %%
plt.figure(figsize=(22,7))
df.corr()['Attrition'].sort_values(ascending = False).drop(['Attrition']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Attrition',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# #### Here we can't see any very high correlation with target column

# %%
#Checking correlation between TotalWorkingYears and JobLevel
plt.figure(figsize=(22,7))
plt.scatter(df.TotalWorkingYears,df.JobLevel)
plt.show()

# %% [markdown]
# #### Good correlation but not too high

# %%
#Checking correlation between MonthlyIncome and JobLevel
plt.figure(figsize=(22,7))
plt.scatter(df.MonthlyIncome,df.JobLevel)
plt.show()

# %% [markdown]
# #### Good correlation but not too high

# %%
#Checking correlation between MonthlyIncome and TotalWorkingYears
plt.figure(figsize=(22,7))
plt.scatter(df.MonthlyIncome,df.TotalWorkingYears)
plt.show()

# %% [markdown]
# #### Can only see slight correlation

# %%
#Checking correlation between Age and TotalWorkingYears
plt.figure(figsize=(22,7))
plt.scatter(df.Age,df.TotalWorkingYears)
plt.show()

# %% [markdown]
# #### We can see very good correlation

# %% [markdown]
# ### Checkin VIF for confirmation of above conclusion:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X = df[['TotalWorkingYears', 'JobLevel', 'MonthlyIncome','Age']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

# %%
print(vif_dF)
# Out:
#              feature        VIF
# 0  TotalWorkingYears   9.293483
# 1           JobLevel  43.427729
# 2      MonthlyIncome  29.132833
# 3                Age   8.339157

# %% [markdown]
# ### As we can see JobLevel and MonthlyIncome highly correlated to Age and TotalWorkingYears

# %% [markdown]
# ### Hence dropping JobLevel and MonthlyIncome :

# %%
#We need to drop JobLevel and MonthlyIncome as they are highly correlated to RA
df = df.drop("JobLevel", axis=1)
df = df.drop("MonthlyIncome", axis=1)

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %% [markdown]
# ### Removing Skewness :

# %%
#Checking skewness
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# ...

# %% [markdown]
# #### Acceptable skewness (-0.65,+0.65)

# %%
#Applying yeo-johnson
from scipy.stats import yeojohnson
df.BusinessTravel = yeojohnson(df.BusinessTravel)[0]
df.DistanceFromHome = yeojohnson(df.DistanceFromHome)[0]
df.NumCompaniesWorked = yeojohnson(df.NumCompaniesWorked)[0]
df.OverTime = yeojohnson(df.OverTime)[0]
df.PercentSalaryHike = yeojohnson(df.PercentSalaryHike)[0]
df.PerformanceRating = yeojohnson(df.PerformanceRating)[0]
df.StockOptionLevel = yeojohnson(df.StockOptionLevel)[0]
df.TotalWorkingYears = yeojohnson(df.TotalWorkingYears)[0]
df.YearsAtCompany = yeojohnson(df.YearsAtCompany)[0]
df.YearsInCurrentRole = yeojohnson(df.YearsInCurrentRole)[0]
df.YearsSinceLastPromotion = yeojohnson(df.YearsSinceLastPromotion)[0]
df.YearsWithCurrManager = yeojohnson(df.YearsWithCurrManager)[0]

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -0.970506
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome           -0.007468
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.014814
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.087019
# TotalWorkingYears          -0.010653
# TrainingTimesLastYear       0.553124
# ...

# %% [markdown]
# #### Since Attrition is target column so we can't remove it's skewness

# %% [markdown]
# ### Removing outliers :

# %%
#Outlier check
df.dtypes
# Out:
# Age                           int64
# Attrition                   float64
# BusinessTravel              float64
# DailyRate                     int64
# Department                  float64
# DistanceFromHome            float64
# Education                     int64
# EducationField              float64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                      float64
# HourlyRate                    int64
# JobInvolvement                int64
# JobRole                     float64
# JobSatisfaction               int64
# MaritalStatus               float64
# MonthlyRate                   int64
# NumCompaniesWorked          float64
# OverTime                    float64
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction      int64
# StockOptionLevel            float64
# TotalWorkingYears           float64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# ...

# %%
#Checking only for continous data types
df.plot.box(layout =(6,5),subplots=True,figsize=(16,20))
# Out:
# Age                            AxesSubplot(0.125,0.772143;0.133621x0.107857)
# Attrition                   AxesSubplot(0.285345,0.772143;0.133621x0.107857)
# BusinessTravel               AxesSubplot(0.44569,0.772143;0.133621x0.107857)
# DailyRate                   AxesSubplot(0.606034,0.772143;0.133621x0.107857)
# Department                  AxesSubplot(0.766379,0.772143;0.133621x0.107857)
# DistanceFromHome               AxesSubplot(0.125,0.642714;0.133621x0.107857)
# Education                   AxesSubplot(0.285345,0.642714;0.133621x0.107857)
# EducationField               AxesSubplot(0.44569,0.642714;0.133621x0.107857)
# EmployeeNumber              AxesSubplot(0.606034,0.642714;0.133621x0.107857)
# EnvironmentSatisfaction     AxesSubplot(0.766379,0.642714;0.133621x0.107857)
# Gender                         AxesSubplot(0.125,0.513286;0.133621x0.107857)
# HourlyRate                  AxesSubplot(0.285345,0.513286;0.133621x0.107857)
# ...

# %% [markdown]
# ### There looks like a outlier in PerformanceRating, TotalWorkingYears, TrainingTimesLastYear and YearsAtCompany columns so now we check with z-score:

# %%
#Outlier removal using z-score
df.shape
# Out:
# (1470, 30)

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
threshhold = 3
np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# #### As we can see there are no outliers

# %% [markdown]
# ## Separating the columns into features and target:

# %%
feature = df.drop("Attrition",axis=1)
target = df["Attrition"]

# %% [markdown]
# ### Upsampling to remove Imbalance classification of Attrition:

# %%
# !pip3 install imbalanced-learn
# Out:
# ...
#      |████████████████████████████████| 199 kB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 199 kB 7.4 MB/s eta 0:00:01
# ...

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

print(Counter(target))

# Using oversampling
oversample = RandomOverSampler(sampling_strategy='minority')

feature_over, target_over = oversample.fit_resample(feature, target)

print(Counter(target_over))
# Out:
# Counter({0.0: 1233, 1.0: 237})
# Counter({1.0: 1233, 0.0: 1233})

# %% [markdown]
# ### Model 1:

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(accuracy_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(accuracy_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.6389452332657201
# At random state 0 the testing accuracy is : 0.6356275303643725
#
#
# At random state 1 the training accuracy is : 0.6364097363083164
# At random state 1 the testing accuracy is : 0.6538461538461539
#
#
# At random state 2 the training accuracy is : 0.59026369168357
# At random state 2 the testing accuracy is : 0.6376518218623481
#
#
# At random state 3 the training accuracy is : 0.652129817444219
# At random state 3 the testing accuracy is : 0.6214574898785425
#
#
# At random state 4 the training accuracy is : 0.6394523326572008
# At random state 4 the testing accuracy is : 0.6477732793522267
#
#
# At random state 5 the training accuracy is : 0.6364097363083164
# At random state 5 the testing accuracy is : 0.6437246963562753
#
#
# At random state 6 the training accuracy is : 0.6288032454361054
# At random state 6 the testing accuracy is : 0.6518218623481782
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = 0)

# %%
lr.fit(features_train,target_train)
# Out:
# LogisticRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(accuracy_score(target_test,pred_test))
# Out:
# 0.6356275303643725

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print("Confusion matrix for model : \n",confusion_matrix(target_test,pred_test))
print("Classification Report for train data : \n",classification_report(target_train,pred_train))
print("Classification Report for test data : \n",classification_report(target_test,pred_test))
# Out:
# Confusion matrix for model :
#  [[154  77]
#  [103 160]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.52      0.51      1002
#          1.0       0.48      0.47      0.48       970
#
#     accuracy                           0.49      1972
#    macro avg       0.49      0.49      0.49      1972
# weighted avg       0.49      0.49      0.49      1972
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.60      0.67      0.63       231
#          1.0       0.68      0.61      0.64       263
#
#     accuracy                           0.64       494
#    macro avg       0.64      0.64      0.64       494
# weighted avg       0.64      0.64      0.64       494

# %% [markdown]
# ### Cross Validation of model:

# %%
Train_accuracy = accuracy_score(target_train,pred_train)
Test_accuracy = accuracy_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature_over,target_over,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.370235198702352 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# At cross fold 3 the cv score is 0.46269261962692615 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# At cross fold 4 the cv score is 0.4991856806078848 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# At cross fold 5 the cv score is 0.5296252802391374 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# At cross fold 6 the cv score is 0.5717761557177615 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# At cross fold 7 the cv score is 0.5502614418159745 and accuracy score for training is 0.4934077079107505 and accuracy score for testing is 0.6356275303643725
#
#
# ...

# %%
from sklearn.metrics import roc_curve
plt.figure(figsize=(8,6))

# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(target_test, pred_test)
lr_fpr1, lr_tpr1, _ = roc_curve(target_train, pred_train)

plt.plot(lr_fpr, lr_tpr, marker='.', label='Logistic Regression', color='r')
plt.plot(lr_fpr1, lr_tpr1, marker='*', label='No skill', color='b')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()
plt.show()

# %% [markdown]
# We can see in the auc-roc curve above

# %% [markdown]
# ### Trying other models:

# %%
def model_selection(algorithm_instance,features_train,target_train,features_test,target_test):
    algorithm_instance.fit(features_train,target_train)
    model_1_pred_train = algorithm_instance.predict(features_train)
    model_1_pred_test = algorithm_instance.predict(features_test)
    print("Accuracy for the training model : ",accuracy_score(target_train,model_1_pred_train))
    print("Accuracy for the testing model : ",accuracy_score(target_test,model_1_pred_test))
    print("Confusion matrix for model : \n",confusion_matrix(target_test,model_1_pred_test))
    print("Classification Report for train data : \n",classification_report(target_train,model_1_pred_train))
    print("Classification Report for test data : \n",classification_report(target_test,model_1_pred_test))
    for j in range(2,10):
        cv_score = cross_val_score(algorithm_instance,feature_over,target_over,cv=j)
        cv_mean = cv_score.mean()
        print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
        print("\n")
        
    #Plotting auc_roc curve
    plt.figure(figsize=(8,6))

    # calculate roc curves
    lr_fpr, lr_tpr, _ = roc_curve(target_test, pred_test)
    lr_fpr1, lr_tpr1, _ = roc_curve(target_train, pred_train)

    plt.plot(lr_fpr, lr_tpr, marker='.', label=algorithm_instance, color='r')
    plt.plot(lr_fpr1, lr_tpr1, marker='*', label='No skill', color='b')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

    plt.legend()
    plt.show()

# %% [markdown]
# ### Model 2:

# %%
from sklearn.svm import SVC
model_selection(SVC(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.5197768762677485
# Accuracy for the testing model :  0.45951417004048584
# Confusion matrix for model :
#  [[131 100]
#  [167  96]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.52      0.64      0.58      1002
#          1.0       0.52      0.39      0.45       970
#
#     accuracy                           0.52      1972
#    macro avg       0.52      0.52      0.51      1972
# weighted avg       0.52      0.52      0.51      1972
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.44      0.57      0.50       231
#          1.0       0.49      0.37      0.42       263
#
#     accuracy                           0.46       494
#    macro avg       0.46      0.47      0.46       494
# weighted avg       0.47      0.46      0.45       494
#
# ...

# %% [markdown]
# ### Model 3:

# %%
from sklearn.neighbors import KNeighborsClassifier
model_selection(KNeighborsClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.8326572008113591
# Accuracy for the testing model :  0.742914979757085
# Confusion matrix for model :
#  [[132  99]
#  [ 28 235]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.94      0.71      0.81      1002
#          1.0       0.76      0.96      0.85       970
#
#     accuracy                           0.83      1972
#    macro avg       0.85      0.83      0.83      1972
# weighted avg       0.85      0.83      0.83      1972
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.57      0.68       231
#          1.0       0.70      0.89      0.79       263
#
#     accuracy                           0.74       494
#    macro avg       0.76      0.73      0.73       494
# weighted avg       0.76      0.74      0.73       494
#
# ...

# %% [markdown]
# ### Model 4:

# %%
from sklearn.tree import DecisionTreeClassifier
model_selection(DecisionTreeClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  1.0
# Accuracy for the testing model :  0.9331983805668016
# Confusion matrix for model :
#  [[199  32]
#  [  1 262]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1002
#          1.0       1.00      1.00      1.00       970
#
#     accuracy                           1.00      1972
#    macro avg       1.00      1.00      1.00      1972
# weighted avg       1.00      1.00      1.00      1972
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.86      0.92       231
#          1.0       0.89      1.00      0.94       263
#
#     accuracy                           0.93       494
#    macro avg       0.94      0.93      0.93       494
# weighted avg       0.94      0.93      0.93       494
#
# ...

# %% [markdown]
# ### Conclusion: Here DecisionTreeClassifier() gives best accuracy hence taking it as main model

# %% [markdown]
# ### Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV

#using 4 parameters
parameters = {'criterion':['entropy','gini'], 'max_features': ["auto","sqrt","log2"], 'min_samples_split' : [2,5,10], 'max_depth':[2,3,5]}
dt = DecisionTreeClassifier()
clf = GridSearchCV(dt,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5}

# %%
rf = DecisionTreeClassifier(criterion = "entropy", max_features = "sqrt", max_depth = 5, min_samples_split = 5)
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = accuracy_score(target_test,pred_decision)
print('Accuracy score: ', abs(rfs)*100)

rfscore = cross_val_score(dt,feature,target,cv=6)
rfc =rfscore.mean()
rfc
print('Cross Validation score: ', abs(rfc)*100)
# Out:
# Accuracy score:  69.23076923076923
# Cross Validation score:  76.39455782312926

# %% [markdown]
# #### Conclusion : We got Accuracy score as 69.23%
