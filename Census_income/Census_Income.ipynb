# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## EDA:

# %%
df = pd.read_csv('census_income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
#Statistical summary
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# #### We have 32560 data rows and 15 columns in the dataframe.

# %%
#Column Data type
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# #### Point to note here is that all columns are not numeric

# %% [markdown]
# ### Checking Null values:

# %%
#Checking null values using heatmap
sns.heatmap(df.isnull())
plt.show()

# %%
#Total number of null values in complete dataset
df.isnull().sum().sum()
# Out:
# 0

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# #### As we can see there are no NULL values in whole dataframe

# %% [markdown]
# ### Histogram Plots :

# %%
#Making dataframe of nominal data
df_visualisation_nominal = df[['Workclass','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']].copy()

# %%
#Visualisation of Workclass data
sns.set(rc={'figure.figsize':(16,4)})
ax = sns.countplot(x='Workclass',data=df_visualisation_nominal)
print(df_visualisation_nominal['Workclass'].value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# **Almost all people are Private working class**

# %%
#Visualisation of Marital_status data
ax = sns.countplot(x='Marital_status',data=df_visualisation_nominal)
print(df_visualisation_nominal['Marital_status'].value_counts())
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %% [markdown]
# **Most people have marital staus as Married-civ-spouse or Never-married**

# %%
#Visualisation of Occupation data
ax = sns.countplot(x='Occupation',data=df_visualisation_nominal)
print(df_visualisation_nominal['Occupation'].value_counts())
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %% [markdown]
# **Occupation wise it is quite diverse**

# %%
#Visualisation of Relationship data
ax = sns.countplot(x='Relationship',data=df_visualisation_nominal)
print(df_visualisation_nominal['Relationship'].value_counts())
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %% [markdown]
# **Most people have realationship status of husband, some are not_in -family, and so on**

# %%
#Visualisation of Race data
ax = sns.countplot(x='Race',data=df_visualisation_nominal)
print(df_visualisation_nominal['Race'].value_counts())
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %% [markdown]
# **Almost all people are white**

# %%
#Visualisation of Sex data
sns.set(rc={'figure.figsize':(6,4)})
ax = sns.countplot(x='Sex',data=df_visualisation_nominal)
print(df_visualisation_nominal['Sex'].value_counts())
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %% [markdown]
# **Most people are male, roughly 2 times**

# %%
#Visualisation of Native_country data
sns.set(rc={'figure.figsize':(20,4)})
ax = sns.countplot(x='Native_country',data=df_visualisation_nominal)
print(df_visualisation_nominal['Native_country'].value_counts())
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64

# %% [markdown]
# **Almost all people are native of USA**

# %%
#Visualisation of Income data
sns.set(rc={'figure.figsize':(6,4)})
ax = sns.countplot(x='Income',data=df_visualisation_nominal)
print(df_visualisation_nominal['Income'].value_counts())
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
# **People having income <=50k is more than 3 times of number of people having income >50k. We can see clearly that our target data is imbalanced**

# %% [markdown]
# ### Density Plots:

# %%
#Making dataframe of Continous data
df_visualisation_continous = df[['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']].copy()

# %%
#Visualisation of Age data
sns.distplot(df_visualisation_continous['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# **It looks skewed right with mode around 35**

# %%
#Visualisation of Fnlwgt data
sns.distplot(df_visualisation_continous['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# **It is skewed right with mode around 0.2**

# %%
#Visualisation of Education_num data
sns.distplot(df_visualisation_continous['Education_num'])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# **It does not look normalized**

# %%
#Visualisation of Capital_gain data
sns.distplot(df_visualisation_continous['Capital_gain'])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# **It looks skewed right**

# %%
#Visualisation of Capital_loss data
sns.distplot(df_visualisation_continous['Capital_loss'])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# **It looks skewed right**

# %%
#Visualisation of Hours_per_week data
sns.distplot(df_visualisation_continous['Hours_per_week'])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# **It does not look normalized**

# %% [markdown]
# ### Pairplot for the continous data columns dataframe:

# %%
sns.pairplot(df_visualisation_continous,height=1.5)

# %% [markdown]
# #### Visualisation is completed

# %% [markdown]
# ### Encoding of Dataframe(Converting String to numeric):

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 3       28        4.0  338409        9.0             13             2.0
# 4       37        4.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0             4.0           0.0   4.0  1.0             0             0
# 1             6.0           1.0   4.0  1.0             0             0
# 2             6.0           0.0   2.0  1.0             0             0
# 3            10.0           5.0   2.0  0.0             0             0
# 4             4.0           5.0   4.0  0.0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555        13.0           5.0   4.0  0.0             0             0
# 32556         7.0           0.0   4.0  1.0             0             0
# 32557         1.0           4.0   4.0  0.0             0             0
# 32558         1.0           3.0   4.0  1.0             0             0
# 32559         4.0           5.0   4.0  0.0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13            39.0     0.0
# 1                  40            39.0     0.0
# 2                  40            39.0     0.0
# 3                  40             5.0     0.0
# 4                  40            39.0     0.0
# ...               ...             ...     ...
# 32555              38            39.0     0.0
# 32556              40            39.0     1.0
# 32557              40            39.0     0.0
# 32558              20            39.0     0.0
# 32559              40            39.0     1.0
#
# [32560 rows x 15 columns]

# %% [markdown]
# ### Correlations:

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df.describe(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Correlation matrix
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# Hours_per_week  0.068756   0.138974 -0.018770   0.055510       0.148127
# Native_country -0.001151  -0.007710 -0.051957   0.064291       0.050831
# Income          0.234039   0.051645 -0.009481   0.079311       0.335182
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.266292   -0.020946     -0.263698  0.028718  0.088832
# Workclass            -0.064798    0.255004     -0.090449  0.049720  0.095942
# Fnlwgt                0.028184    0.001554      0.008922 -0.021278  0.026882
# Education            -0.038398   -0.021274     -0.010879  0.014135 -0.027349
# Education_num        -0.069338    0.109748     -0.094145  0.031825  0.012256
# Marital_status        1.000000   -0.009617      0.185461 -0.068025 -0.129337
# Occupation           -0.009617    1.000000     -0.075620  0.006779  0.080328
# Relationship          0.185461   -0.075620      1.000000 -0.116052 -0.582453
# Race                 -0.068025    0.006779     -0.116052  1.000000  0.087197
# Sex                  -0.129337    0.080328     -0.582453  0.087197  1.000000
# Capital_gain         -0.043398    0.025511     -0.057918  0.011143  0.048477
# Capital_loss         -0.034182    0.017979     -0.061064  0.018902  0.045572
# Hours_per_week       -0.190521    0.080384     -0.248975  0.041910  0.229312
# Native_country       -0.023827   -0.012532     -0.005504  0.137849 -0.008125
# Income               -0.199295    0.075448     -0.250924  0.071853  0.215995
#
#                 Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# Age                 0.077674      0.057775        0.068756       -0.001151
# Workclass           0.033828      0.012231        0.138974       -0.007710
# Fnlwgt              0.000437     -0.010259       -0.018770       -0.051957
# Education           0.030047      0.016744        0.055510        0.064291
# Education_num       0.122627      0.079932        0.148127        0.050831
# Marital_status     -0.043398     -0.034182       -0.190521       -0.023827
# Occupation          0.025511      0.017979        0.080384       -0.012532
# Relationship       -0.057918     -0.061064       -0.248975       -0.005504
# Race                0.011143      0.018902        0.041910        0.137849
# Sex                 0.048477      0.045572        0.229312       -0.008125
# Capital_gain        1.000000     -0.031614        0.078409       -0.001984
# Capital_loss       -0.031614      1.000000        0.054256        0.000420
# Hours_per_week      0.078409      0.054256        1.000000       -0.002671
# Native_country     -0.001984      0.000420       -0.002671        1.000000
# Income              0.223333      0.150523        0.229690        0.015845
#
#                   Income
# Age             0.234039
# Workclass       0.051645
# Fnlwgt         -0.009481
# Education       0.079311
# Education_num   0.335182
# Marital_status -0.199295
# Occupation      0.075448
# Relationship   -0.250924
# Race            0.071853
# Sex             0.215995
# Capital_gain    0.223333
# Capital_loss    0.150523
# Hours_per_week  0.229690
# Native_country  0.015845
# Income          1.000000

# %%
#Correlation of Columns with target column using heatmap
plt.figure(figsize = (25,25))
sns.heatmap(df.corr(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here we can't see any high correlation as highest is 0.58

# %%
#Checking columns which appear to be highly correlated with target columns

# %%
plt.figure(figsize=(22,7))
df.corr()['Income'].sort_values(ascending = False).drop(['Income']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Income',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# #### Here we can't see any very high correlation with target column

# %%
#Checking correlation between Income and Education_num
plt.figure(figsize=(22,7))
plt.scatter(df.Income,df.Education_num)
plt.show()

# %% [markdown]
# #### We can't see any correlation between these 2

# %%
#Checking correlation between Sex and Relationship
plt.figure(figsize=(22,7))
plt.scatter(df.Sex,df.Relationship)
plt.show()

# %% [markdown]
# #### We can't see any correlation between these 2

# %% [markdown]
# ### Checkin VIF for confirmation of above conclusion:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X1 = df[['Income', 'Education_num']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X1.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X1.values, i)
                          for i in range(len(X1.columns))]

# %%
print(vif_dF)
# Out:
#          feature       VIF
# 0         Income  1.428541
# 1  Education_num  1.428541

# %% [markdown]
# ### As we can see there is low correlation

# %%
X2 = df[['Sex','Relationship']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X2.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X2.values, i)
                          for i in range(len(X2.columns))]

# %%
print(vif_dF)
# Out:
#         feature       VIF
# 0           Sex  1.097688
# 1  Relationship  1.097688

# %% [markdown]
# ### As we can see here correlation is low (< 10)

# %% [markdown]
# ### Removing Skewness :

# %%
#Checking skewness
df.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %% [markdown]
# #### Acceptable skewness (-0.65,+0.65)

# %%
from scipy.stats import yeojohnson
df.Fnlwgt = yeojohnson(df.Fnlwgt)[0]
df.Capital_gain = yeojohnson(df.Capital_gain)[0]
df.Capital_loss = yeojohnson(df.Capital_loss)[0]

# %% [markdown]
# #### Now all continous columns are in acceptable skew range

# %% [markdown]
# ### Removing outliers :

# %%
#Outlier check
df.dtypes
# Out:
# Age                 int64
# Workclass         float64
# Fnlwgt            float64
# Education         float64
# Education_num       int64
# Marital_status    float64
# Occupation        float64
# Relationship      float64
# Race              float64
# Sex               float64
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week      int64
# Native_country    float64
# Income            float64
# dtype: object

# %%
#Checking only for continous data types
df.plot.box(layout =(6,8),subplots=True,figsize=(16,20))
# Out:
# Age                  AxesSubplot(0.125,0.772143;0.0824468x0.107857)
# Workclass         AxesSubplot(0.223936,0.772143;0.0824468x0.107857)
# Fnlwgt            AxesSubplot(0.322872,0.772143;0.0824468x0.107857)
# Education         AxesSubplot(0.421809,0.772143;0.0824468x0.107857)
# Education_num     AxesSubplot(0.520745,0.772143;0.0824468x0.107857)
# Marital_status    AxesSubplot(0.619681,0.772143;0.0824468x0.107857)
# Occupation        AxesSubplot(0.718617,0.772143;0.0824468x0.107857)
# Relationship      AxesSubplot(0.817553,0.772143;0.0824468x0.107857)
# Race                 AxesSubplot(0.125,0.642714;0.0824468x0.107857)
# Sex               AxesSubplot(0.223936,0.642714;0.0824468x0.107857)
# Capital_gain      AxesSubplot(0.322872,0.642714;0.0824468x0.107857)
# Capital_loss      AxesSubplot(0.421809,0.642714;0.0824468x0.107857)
# Hours_per_week    AxesSubplot(0.520745,0.642714;0.0824468x0.107857)
# Native_country    AxesSubplot(0.619681,0.642714;0.0824468x0.107857)
# Income            AxesSubplot(0.718617,0.642714;0.0824468x0.107857)
# dtype: object

# %% [markdown]
# ### There looks like outliers in some columns so now we check with z-score:

# %%
#Outlier removal using z-score
df.shape
# Out:
# (32560, 15)

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
threshhold = 3
np.where(z>3)
# Out:
# (array([    3,     7,     8, ..., 32550, 32552, 32559]),
#  array([13, 10, 10, ...,  8,  8, 10]))

# %%
df_new_z = df[(z<3).all(axis = 1)]
df_new_z
# Out:
#        Age  Workclass      Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0  274.417665        9.0             13             2.0
# 1       38        4.0  410.194889       11.0              9             0.0
# 2       53        4.0  425.134766        1.0              7             2.0
# 4       37        4.0  461.129813       12.0             14             2.0
# 5       49        4.0  361.801023        6.0              5             3.0
# ...    ...        ...         ...        ...            ...             ...
# 32554   22        4.0  478.172525       15.0             10             4.0
# 32555   27        4.0  441.936377        7.0             12             2.0
# 32556   40        4.0  356.195231       11.0              9             2.0
# 32557   58        4.0  353.782108       11.0              9             6.0
# 32558   22        4.0  398.604480       11.0              9             4.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0             4.0           0.0   4.0  1.0          -0.0          -0.0
# 1             6.0           1.0   4.0  1.0          -0.0          -0.0
# 2             6.0           0.0   2.0  1.0          -0.0          -0.0
# 4             4.0           5.0   4.0  0.0          -0.0          -0.0
# 5             8.0           1.0   2.0  0.0          -0.0          -0.0
# ...           ...           ...   ...  ...           ...           ...
# 32554        11.0           1.0   4.0  1.0          -0.0          -0.0
# 32555        13.0           5.0   4.0  0.0          -0.0          -0.0
# 32556         7.0           0.0   4.0  1.0          -0.0          -0.0
# 32557         1.0           4.0   4.0  0.0          -0.0          -0.0
# 32558         1.0           3.0   4.0  1.0          -0.0          -0.0
#
#        Hours_per_week  Native_country  Income
# 0                  13            39.0     0.0
# 1                  40            39.0     0.0
# 2                  40            39.0     0.0
# 4                  40            39.0     0.0
# 5                  16            23.0     0.0
# ...               ...             ...     ...
# 32554              40            39.0     0.0
# 32555              38            39.0     0.0
# 32556              40            39.0     1.0
# 32557              40            39.0     0.0
# 32558              20            39.0     0.0
#
# [25342 rows x 15 columns]

# %%
df_new_z.shape
# Out:
# (25342, 15)

# %%
#Data Loss
Data_loss = (32560-25342)/32560*100
Data_loss
# Out:
# 22.168304668304668

# %% [markdown]
# #### As we can see too much data loss so it is much better to leave outlier and use tree algorithm

# %% [markdown]
# ## Separating the columns into features and target:

# %%
feature = df.drop("Income",axis=1)
target = df["Income"]

# %% [markdown]
# ### Upsampling to remove Imbalance classification of target variable (Income):

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

print(Counter(target))

# Using oversampling
oversample = RandomOverSampler(sampling_strategy='minority')

feature_over, target_over = oversample.fit_resample(feature, target)

print(Counter(target_over))
# Out:
# Counter({0.0: 24719, 1.0: 7841})
# Counter({0.0: 24719, 1.0: 24719})

# %% [markdown]
# ### Model 1:

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(accuracy_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(accuracy_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.7180530973451328
# At random state 0 the testing accuracy is : 0.7286610032362459
#
#
# At random state 1 the training accuracy is : 0.721795195954488
# At random state 1 the testing accuracy is : 0.7124797734627831
#
#
# At random state 2 the training accuracy is : 0.7207838179519596
# At random state 2 the testing accuracy is : 0.7333131067961165
#
#
# At random state 3 the training accuracy is : 0.7195701643489254
# At random state 3 the testing accuracy is : 0.7184466019417476
#
#
# At random state 4 the training accuracy is : 0.7250316055625791
# At random state 4 the testing accuracy is : 0.7091423948220065
#
#
# At random state 5 the training accuracy is : 0.7214159292035398
# At random state 5 the testing accuracy is : 0.7152103559870551
#
#
# At random state 6 the training accuracy is : 0.7186346396965866
# At random state 6 the testing accuracy is : 0.725121359223301
#
#
# At random state 7 the training accuracy is : 0.7193678887484197
# At random state 7 the testing accuracy is : 0.7230987055016181
#
#
# At random state 8 the training accuracy is : 0.7221238938053097
# At random state 8 the testing accuracy is : 0.7181432038834952
#
#
# At random state 9 the training accuracy is : 0.7326169405815424
# At random state 9 the testing accuracy is : 0.7291666666666666

# %%
features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = 5)

# %%
lr.fit(features_train,target_train)
# Out:
# LogisticRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(accuracy_score(target_test,pred_test))
# Out:
# 0.7152103559870551

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print("Confusion matrix for model : \n",confusion_matrix(target_test,pred_test))
print("Classification Report for train data : \n",classification_report(target_train,pred_train))
print("Classification Report for test data : \n",classification_report(target_test,pred_test))
# Out:
# Confusion matrix for model :
#  [[3307 1621]
#  [1195 3765]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.46      0.48     19791
#          1.0       0.50      0.54      0.52     19759
#
#     accuracy                           0.50     39550
#    macro avg       0.50      0.50      0.50     39550
# weighted avg       0.50      0.50      0.50     39550
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.73      0.67      0.70      4928
#          1.0       0.70      0.76      0.73      4960
#
#     accuracy                           0.72      9888
#    macro avg       0.72      0.72      0.71      9888
# weighted avg       0.72      0.72      0.71      9888

# %% [markdown]
# ### Cross Validation of model:

# %%
Train_accuracy = accuracy_score(target_train,pred_train)
Test_accuracy = accuracy_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature_over,target_over,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.7333427727658886 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 3 the cv score is 0.7250089895720965 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 4 the cv score is 0.719669071004425 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 5 the cv score is 0.7263439630772716 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 6 the cv score is 0.7243213860512654 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 7 the cv score is 0.7242606867577592 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 8 the cv score is 0.7235932065284283 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551
#
#
# At cross fold 9 the cv score is 0.7230673701864059 and accuracy score for training is 0.5007585335018964 and accuracy score for testing is 0.7152103559870551

# %%
from sklearn.metrics import roc_curve
plt.figure(figsize=(8,6))

# calculate roc curves
lr_fpr, lr_tpr, _ = roc_curve(target_test, pred_test)
lr_fpr1, lr_tpr1, _ = roc_curve(target_train, pred_train)

plt.plot(lr_fpr, lr_tpr, marker='.', label='Logistic Regression', color='r')
plt.plot(lr_fpr1, lr_tpr1, marker='*', label='No skill', color='b')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()
plt.show()

# %% [markdown]
# We can see in the auc-roc curve above

# %% [markdown]
# ### Trying other models:

# %%
def model_selection(algorithm_instance,features_train,target_train,features_test,target_test):
    algorithm_instance.fit(features_train,target_train)
    model_1_pred_train = algorithm_instance.predict(features_train)
    model_1_pred_test = algorithm_instance.predict(features_test)
    print("Accuracy for the training model : ",accuracy_score(target_train,model_1_pred_train))
    print("Accuracy for the testing model : ",accuracy_score(target_test,model_1_pred_test))
    print("Confusion matrix for model : \n",confusion_matrix(target_test,model_1_pred_test))
    print("Classification Report for train data : \n",classification_report(target_train,model_1_pred_train))
    print("Classification Report for test data : \n",classification_report(target_test,model_1_pred_test))
    
    Train_accuracy = accuracy_score(target_train,model_1_pred_train)
    Test_accuracy = accuracy_score(target_test,model_1_pred_test)
    
    for j in range(2,10):
        cv_score = cross_val_score(algorithm_instance,feature_over,target_over,cv=j)
        cv_mean = cv_score.mean()
        print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
        print("\n")
        
    #Plotting auc_roc curve
    plt.figure(figsize=(8,6))

    # calculate roc curves
    lr_fpr, lr_tpr, _ = roc_curve(target_test, model_1_pred_test)
    lr_fpr1, lr_tpr1, _ = roc_curve(target_train, pred_train)

    plt.plot(lr_fpr, lr_tpr, marker='.', label=algorithm_instance, color='r')
    plt.plot(lr_fpr1, lr_tpr1, marker='*', label='No skill', color='b')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

    plt.legend()
    plt.show()

# %% [markdown]
# ### Model 2:

# %%
from sklearn.neighbors import KNeighborsClassifier
model_selection(KNeighborsClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.8439696586599241
# Accuracy for the testing model :  0.7617313915857605
# Confusion matrix for model :
#  [[3287 1641]
#  [ 715 4245]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83     19791
#          1.0       0.79      0.94      0.86     19759
#
#     accuracy                           0.84     39550
#    macro avg       0.86      0.84      0.84     39550
# weighted avg       0.86      0.84      0.84     39550
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.67      0.74      4928
#          1.0       0.72      0.86      0.78      4960
#
#     accuracy                           0.76      9888
#    macro avg       0.77      0.76      0.76      9888
# weighted avg       0.77      0.76      0.76      9888
#
# At cross fold 2 the cv score is 0.7508596626077106 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 3 the cv score is 0.7668798130542137 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 4 the cv score is 0.7679115438325542 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 5 the cv score is 0.770318682831203 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 6 the cv score is 0.773777719611242 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 7 the cv score is 0.7749308180209773 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 8 the cv score is 0.7762251539953418 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605
#
#
# At cross fold 9 the cv score is 0.7763667531276582 and accuracy score for training is 0.8439696586599241 and accuracy score for testing is 0.7617313915857605

# %% [markdown]
# ### Model 3:

# %%
from sklearn.tree import DecisionTreeClassifier
model_selection(DecisionTreeClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  1.0
# Accuracy for the testing model :  0.9103964401294499
# Confusion matrix for model :
#  [[4200  728]
#  [ 158 4802]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     19791
#          1.0       1.00      1.00      1.00     19759
#
#     accuracy                           1.00     39550
#    macro avg       1.00      1.00      1.00     39550
# weighted avg       1.00      1.00      1.00     39550
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.85      0.90      4928
#          1.0       0.87      0.97      0.92      4960
#
#     accuracy                           0.91      9888
#    macro avg       0.92      0.91      0.91      9888
# weighted avg       0.92      0.91      0.91      9888
#
# At cross fold 2 the cv score is 0.8928556980460375 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 3 the cv score is 0.9137912175071893 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 4 the cv score is 0.9158950583946135 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 5 the cv score is 0.9203652159368503 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 6 the cv score is 0.9225699505784116 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 7 the cv score is 0.9236826428046702 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 8 the cv score is 0.9249567710551083 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499
#
#
# At cross fold 9 the cv score is 0.924815158767813 and accuracy score for training is 1.0 and accuracy score for testing is 0.9103964401294499

# %% [markdown]
# ### Model 4:

# %%
from sklearn.ensemble import RandomForestClassifier
model_selection(RandomForestClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  1.0
# Accuracy for the testing model :  0.9291059870550162
# Confusion matrix for model :
#  [[4349  579]
#  [ 122 4838]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     19791
#          1.0       1.00      1.00      1.00     19759
#
#     accuracy                           1.00     39550
#    macro avg       1.00      1.00      1.00     39550
# weighted avg       1.00      1.00      1.00     39550
#
# Classification Report for test data :
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.88      0.93      4928
#          1.0       0.89      0.98      0.93      4960
#
#     accuracy                           0.93      9888
#    macro avg       0.93      0.93      0.93      9888
# weighted avg       0.93      0.93      0.93      9888
#
# At cross fold 2 the cv score is 0.9133662364982402 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 3 the cv score is 0.9291639724953461 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 4 the cv score is 0.930094544127663 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 5 the cv score is 0.9337961480915575 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 6 the cv score is 0.9362638342738833 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 7 the cv score is 0.938023766714416 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 8 the cv score is 0.9380033589341914 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162
#
#
# At cross fold 9 the cv score is 0.938630398012233 and accuracy score for training is 1.0 and accuracy score for testing is 0.9291059870550162

# %% [markdown]
# ### Conclusion: Here RandomForestClassifier() gives best accuracy hence taking it as main model

# %% [markdown]
# ### Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV

#using 4 parameters
parameters = {'criterion':['entropy','gini'], 'max_features': ["auto","sqrt","log2"], 'min_samples_split' : [2,5,10], 'max_depth':[2,3,5]}
rf = RandomForestClassifier()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2}

# %%
rf = RandomForestClassifier(criterion = "gini", max_features = "log2", max_depth = 5, min_samples_split = 2)
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = accuracy_score(target_test,pred_decision)
print('Accuracy score: ', abs(rfs)*100)

rfscore = cross_val_score(rf,feature,target,cv=6)
rfc =rfscore.mean()
rfc
print('Cross Validation score: ', abs(rfc)*100)
# Out:
# Accuracy score:  81.23988673139159
# Cross Validation score:  84.40419810545775

# %% [markdown]
# ### Conclusion : We got Accuracy score as 81.24%
