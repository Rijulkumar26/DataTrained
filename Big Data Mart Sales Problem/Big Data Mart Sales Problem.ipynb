# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('bigdatamart_Train.csv')
df2 = pd.read_csv('bigdatamart_Test.csv')

# %%
df3 = df2.copy()

# %%
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Statistical summary
df1.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df1.shape
# Out:
# (8523, 12)

# %%
#Column Data type
df1.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#Checking null values using heatmap
sns.heatmap(df1.isnull())
plt.show()

# %%
#Total number of null values in complete dataset
df1.isnull().sum().sum()
# Out:
# 3873

# %%
#number of null values in each column
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#Replacing missing values of Item_Weight with mean values
mean_weight = df1.Item_Weight.mean()
df1.Item_Weight.fillna(mean_weight,inplace=True)

# %%
mean_weight = df2.Item_Weight.mean()
df2.Item_Weight.fillna(mean_weight,inplace=True)

# %%
#Replacing missing values of Outlet_Size with mode values
mode_size = df1.Outlet_Size.mode()
df1.Outlet_Size.fillna(mode_size[0],inplace=True)

# %%
mode_size = df2.Outlet_Size.mode()
df2.Outlet_Size.fillna(mode_size[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
#Making dataframe of nominal data
df1_visualisation_nominal = df1[['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type']].copy()

# %%
#Visualisation of Item_Fat_Content data
ax = sns.countplot(x='Item_Fat_Content',data=df1_visualisation_nominal)
print(df1_visualisation_nominal['Item_Fat_Content'].value_counts())
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
#Visualisation of Item_Type data
sns.set(rc={'figure.figsize':(22,12)})
ax = sns.countplot(x='Item_Type',data=df1_visualisation_nominal)
print(df1_visualisation_nominal['Item_Type'].value_counts())
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
#Visualisation of Outlet_Size data
sns.set(rc={'figure.figsize':(6,5)})
ax = sns.countplot(x='Outlet_Size',data=df1_visualisation_nominal)
print(df1_visualisation_nominal['Outlet_Size'].value_counts())
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
#Visualisation of Outlet_Location_Type data
ax = sns.countplot(x='Outlet_Location_Type',data=df1_visualisation_nominal)
print(df1_visualisation_nominal['Outlet_Location_Type'].value_counts())
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
#Visualisation of Outlet_Type data
ax = sns.countplot(x='Outlet_Type',data=df1_visualisation_nominal)
print(df1_visualisation_nominal['Outlet_Type'].value_counts())
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
#Making dataframe of Continous data
df1_visualisation_continous = df1[['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales']].copy()

# %%
#Visualisation of Item_Weight data
sns.distplot(df1_visualisation_continous['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
#Visualisation of Item_Visibility data
sns.distplot(df_visualisation_continous['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
#Visualisation of Item_Visibility data
sns.distplot(df_visualisation_continous['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
#Visualisation of Item_Visibility data
sns.distplot(df_visualisation_continous['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# Visualisation is completed

# %% [markdown]
# Encoding of Dataframe(Converting String to numeric):

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in df1.columns:
    if df1[i].dtypes == "object":
        df1[i] = enc.fit_transform(df1[i].values.reshape(-1,1))

# %%
for j in df2.columns:
    if df2[j].dtypes == "object":
        df2[j] = enc.fit_transform(df2[j].values.reshape(-1,1))

# %%
df1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df1.describe(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Correlation of Columns with target column
df1.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.044518         -0.098114
# Item_Weight                       0.044518     1.000000         -0.017331
# Item_Fat_Content                 -0.098114    -0.017331          1.000000
# Item_Visibility                  -0.025482    -0.012049          0.034042
# Item_Type                        -0.017973     0.028015         -0.115958
# Item_MRP                          0.012853     0.024756         -0.000876
# Outlet_Identifier                -0.008602    -0.007975         -0.002357
# Outlet_Establishment_Year        -0.012772    -0.008301         -0.000189
# Outlet_Size                       0.001389    -0.007225         -0.012058
# Outlet_Location_Type              0.003656     0.004088         -0.004102
# Outlet_Type                      -0.001178    -0.000566         -0.004214
# Item_Outlet_Sales                 0.002869     0.011550          0.009800
#
# ...

# %%
#Correlation of Columns with target column using heatmap
plt.figure(figsize = (22,7))
sns.heatmap(df1.corr(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Checking columns which appear to be highly correlated with target columns

# %%
plt.figure(figsize=(22,7))
df1.corr()['Item_Outlet_Sales'].sort_values(ascending = False).drop(['Item_Outlet_Sales']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Column with target names',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %%
#Checking correlation between Item_MRP and Item_Outlet_Sales
plt.figure(figsize=(22,7))
plt.scatter(df1.Item_MRP,df1.Item_Outlet_Sales)
plt.show()

# %%
# calculate covariance matrix between TV and sales
covariance = np.cov(df1.Item_MRP,df1.Item_Outlet_Sales)
print(covariance)
# Out:
# [[   3878.1839091    60317.48561204]
#  [  60317.48561204 2912140.93849972]]

# %% [markdown]
# The covariance between the two variables is 350.39 . We can see that variables change in the same direction.

# %%
#Using pearson's correlation
from scipy.stats import pearsonr
corr, _ = pearsonr(df1.Item_MRP,df1.Item_Outlet_Sales)
corr
# Out:
# 0.5675744466569193

# %% [markdown]
# As we can see that it is good correlation but not very high correlation

# %%
#Checking correlation between Outlet_Location_Type and Outlet_Identifier
plt.figure(figsize=(22,7))
plt.scatter(df1.Outlet_Location_Type,df1.Outlet_Identifier)
plt.show()

# %%
#Removing skewness
df1.skew()
# Out:
# Item_Identifier             -0.008877
# Item_Weight                  0.090561
# Item_Fat_Content             0.994824
# Item_Visibility              1.167091
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Identifier           -0.059861
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# Acceptable skewness (-0.65,+0.65) and not done for target variable and categorical

# %%
#Applying box-cox
from scipy.stats import yeojohnson
df1.Item_Visibility = yeojohnson(df1.Item_Visibility)[0]

# %%
df1.skew()
# Out:
# Item_Identifier             -0.008877
# Item_Weight                  0.090561
# Item_Fat_Content             0.994824
# Item_Visibility              0.124279
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Identifier           -0.059861
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
#Outlier check
df1.dtypes
# Out:
# Item_Identifier              float64
# Item_Weight                  float64
# Item_Fat_Content             float64
# Item_Visibility              float64
# Item_Type                    float64
# Item_MRP                     float64
# Outlet_Identifier            float64
# Outlet_Establishment_Year      int64
# Outlet_Size                  float64
# Outlet_Location_Type         float64
# Outlet_Type                  float64
# Item_Outlet_Sales            float64
# dtype: object

# %%
#Item_Weight, Item_Visibility, Item_MRP and Item_Outlet_Sales are the only continous data types
df1['Item_Weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1['Item_Visibility'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1['Item_MRP'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1['Item_Outlet_Sales'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Item_Outlet_Sales is Target variable so we can ignore outliers and rest continous data has no outliers

# %% [markdown]
# Separating the columns into features and target:

# %%
feature = df1.drop("Item_Outlet_Sales",axis=1)
target = df1["Item_Outlet_Sales"]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(r2_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(r2_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.5090660702263164
# At random state 0 the testing accuracy is : 0.5122334526025538
#
#
# At random state 1 the training accuracy is : 0.5098034304563401
# At random state 1 the testing accuracy is : 0.5085486319155996
#
#
# At random state 2 the training accuracy is : 0.5136457207427965
# At random state 2 the testing accuracy is : 0.4937950727891386
#
#
# At random state 3 the training accuracy is : 0.5008951366887344
# At random state 3 the testing accuracy is : 0.5437054604212652
#
#
# At random state 4 the training accuracy is : 0.5121712959434801
# At random state 4 the testing accuracy is : 0.49764785392487865
#
#
# At random state 5 the training accuracy is : 0.5117044416645109
# At random state 5 the testing accuracy is : 0.5014045752667085
#
#
# At random state 6 the training accuracy is : 0.5098890233637712
# At random state 6 the testing accuracy is : 0.5080273877601503
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = 25)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.498313396558005

# %% [markdown]
# Cross Validation of model

# %%
Train_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature,target,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.5073871274919569 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# At cross fold 3 the cv score is 0.5077206935607034 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# At cross fold 4 the cv score is 0.5060519306401058 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# At cross fold 5 the cv score is 0.5073226825628003 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# At cross fold 6 the cv score is 0.5071138946373231 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# At cross fold 7 the cv score is 0.5078634635317704 and accuracy score for training is -0.4966294236369744 and accuracy score for testing is 0.498313396558005
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# linear Regression gives good results.

# %% [markdown]
# Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls = Lasso(alpha = 0.1, random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.49837105426488315

# %%
cv_score = cross_val_score(ls,feature,target,cv=2)
cv_mean =cv_score.mean()
cv_mean
# Out:
# 0.5073877579755844

# %% [markdown]
# Predicting Item_Outlet_Sales for test dataset

# %%
features_test2 = df2
pred_test2 = lr.predict(features_test2)

# %%
pred_test2
# Out:
# array([2115.96440989, 1182.17493962, 2085.35098355, ..., 1783.1349186 ,
#        3208.23638701, 1140.79342857])

# %%
pred_sale = pd.DataFrame({'Predicted Sale': pred_test2})
pred_sale
# Out:
#       Predicted Sale
# 0        2115.964410
# 1        1182.174940
# 2        2085.350984
# 3        2196.317973
# 4        4895.935928
# ...              ...
# 5676     2266.404039
# 5677     2825.138619
# 5678     1783.134919
# 5679     3208.236387
# 5680     1140.793429
#
# [5681 rows x 1 columns]

# %%
output = pd.concat([df3, pred_sale], axis=1)
output
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...
