# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## EDA:

# %%
df = pd.read_csv('database_IND.csv')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
#Statistical summary
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %%
df.shape
# Out:
# (907, 27)

# %% [markdown]
# #### We have 907 data rows and 27 columns in the dataframe.

# %%
#Column Data type
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# #### Point to note here is that all columns are not numeric

# %% [markdown]
# ### Checking Null values:

# %%
#Checking null values using heatmap
sns.heatmap(df.isnull())
plt.show()

# %%
#Total number of null values in complete dataset
df.isnull().sum().sum()
# Out:
# 10445

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# #### As we can see there are NULL values in whole dataframe

# %% [markdown]
# ### We can see that some columns are completely filled with NULL values so dropping them

# %%
df.drop('other_fuel2', axis=1, inplace=True)
df.drop('other_fuel3', axis=1, inplace=True)
df.drop('wepp_id', axis=1, inplace=True)
df.drop('generation_gwh_2013', axis=1, inplace=True)
df.drop('generation_gwh_2019', axis=1, inplace=True)
df.drop('estimated_generation_gwh', axis=1, inplace=True)

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %% [markdown]
# ### Replacing NULL values:

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i].fillna(df[i].mode()[0],inplace=True)

# %%
for i in df.columns:
    if (df[i].dtypes != "object"):
        df[i].fillna(df[i].mean(),inplace=True)

# %%
#number of null values in complete dataset
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Now we can see there are no NULL values in whole dataframe

# %%
#Column Data type
df.dtypes
# Out:
# country                    object
# country_long               object
# name                       object
# gppd_idnr                  object
# capacity_mw               float64
# latitude                  float64
# longitude                 float64
# primary_fuel               object
# other_fuel1                object
# commissioning_year        float64
# owner                      object
# source                     object
# url                        object
# geolocation_source         object
# year_of_capacity_data     float64
# generation_gwh_2014       float64
# generation_gwh_2015       float64
# generation_gwh_2016       float64
# generation_gwh_2017       float64
# generation_gwh_2018       float64
# generation_data_source     object
# dtype: object

# %% [markdown]
# ### Histogram Plots :

# %%
#Making dataframe of nominal data
df_visualisation_nominal = df[['country','country_long','primary_fuel','other_fuel1','geolocation_source','generation_data_source','year_of_capacity_data']].copy()

# %%
#Visualisation of country data
ax = sns.countplot(x='country',data=df_visualisation_nominal)
print(df_visualisation_nominal['country'].value_counts())
# Out:
# IND    907
# Name: country, dtype: int64

# %% [markdown]
# **Almost power plants are Indian**

# %%
#Visualisation of country_long data
ax = sns.countplot(x='country_long',data=df_visualisation_nominal)
print(df_visualisation_nominal['country_long'].value_counts())
# Out:
# India    907
# Name: country_long, dtype: int64

# %% [markdown]
# **All power plants in this study are Indian**

# %%
#Visualisation of primary_fuel data
ax = sns.countplot(x='primary_fuel',data=df_visualisation_nominal)
print(df_visualisation_nominal['primary_fuel'].value_counts())
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# **Power plants use diverse type of fuels but coal and hydro are most commonly used primary fuels**

# %%
#Visualisation of other_fuel1 data
ax = sns.countplot(x='other_fuel1',data=df_visualisation_nominal)
print(df_visualisation_nominal['other_fuel1'].value_counts())
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# **Almost all other fuel used is oil**

# %%
#Visualisation of geolocation_source data
ax = sns.countplot(x='geolocation_source',data=df_visualisation_nominal)
print(df_visualisation_nominal['geolocation_source'].value_counts())
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %% [markdown]
# **Most of the time geolocation source is from WRI and some from Industry about, rest are from laboratory**

# %%
#Visualisation of generation_data_source data
ax = sns.countplot(x='generation_data_source',data=df_visualisation_nominal)
print(df_visualisation_nominal['generation_data_source'].value_counts())
# Out:
# Central Electricity Authority    907
# Name: generation_data_source, dtype: int64

# %% [markdown]
# **All generation data source is Central Electricity Authority**

# %%
#Visualisation of year_of_capacity_data data
ax = sns.countplot(x='year_of_capacity_data',data=df_visualisation_nominal)
print(df_visualisation_nominal['year_of_capacity_data'].value_counts())
# Out:
# 2019.0    907
# Name: year_of_capacity_data, dtype: int64

# %% [markdown]
# **All year of capacity data is 2019**

# %% [markdown]
# ### We can see that some columns are completely filled with 1 value so dropping them

# %%
df.drop('generation_data_source', axis=1, inplace=True)
df.drop('country_long', axis=1, inplace=True)
df.drop('country', axis=1, inplace=True)
df.drop('year_of_capacity_data', axis=1, inplace=True)

# %%
#Column Data type
df.dtypes
# Out:
# name                    object
# gppd_idnr               object
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# other_fuel1             object
# commissioning_year     float64
# owner                   object
# source                  object
# url                     object
# geolocation_source      object
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# generation_gwh_2018    float64
# dtype: object

# %% [markdown]
# ### Density Plots:

# %%
#Making dataframe of Continous data
df_visualisation_continous = df[['capacity_mw','latitude','longitude','commissioning_year','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']].copy()

# %%
#Visualisation of capacity_mw data
sns.distplot(df_visualisation_continous['capacity_mw'])
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %% [markdown]
# **It looks skewed right with mode around 0**

# %%
#Visualisation of latitude data
sns.distplot(df_visualisation_continous['latitude'])
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %% [markdown]
# **It looks normalised with a slight distortion and mode near 20**

# %%
#Visualisation of longitude data
sns.distplot(df_visualisation_continous['longitude'])
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='Density'>

# %% [markdown]
# **It is skewed right with mode near 77**

# %%
#Visualisation of commissioning_year data
sns.distplot(df_visualisation_continous['commissioning_year'])
# Out:
# <AxesSubplot:xlabel='commissioning_year', ylabel='Density'>

# %% [markdown]
# **It looks skewed left with mode around 1997**

# %%
#Visualisation of generation_gwh_2014 data
sns.distplot(df_visualisation_continous['generation_gwh_2014'])
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='Density'>

# %% [markdown]
# **It is skewed right with mode near 2500**

# %%
#Visualisation of generation_gwh_2015 data
sns.distplot(df_visualisation_continous['generation_gwh_2015'])
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='Density'>

# %% [markdown]
# **It is skewed right with mode near 2500**

# %%
#Visualisation of generation_gwh_2016 data
sns.distplot(df_visualisation_continous['generation_gwh_2016'])
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='Density'>

# %% [markdown]
# **It looks skewed right with mode near 2500**

# %%
#Visualisation of generation_gwh_2017 data
sns.distplot(df_visualisation_continous['generation_gwh_2017'])
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='Density'>

# %% [markdown]
# **It is skewed right with mode near 2500**

# %%
#Visualisation of generation_gwh_2018 data
sns.distplot(df_visualisation_continous['generation_gwh_2018'])
# Out:
# <AxesSubplot:xlabel='generation_gwh_2018', ylabel='Density'>

# %% [markdown]
# **It looks skewed right with mode near 2500**

# %% [markdown]
# ### Pairplot for the continous data columns dataframe:

# %%
sns.pairplot(df_visualisation_continous,height=2.5)

# %% [markdown]
# #### Visualisation is completed

# %% [markdown]
# ### Encoding of Dataframe(Converting String to numeric):

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0      0.0      657.0          2.5   28.1839    73.2407           6.0
# 1      1.0      519.0         98.0   24.7663    74.6090           1.0
# 2      2.0      853.0         39.2   21.9038    69.3732           7.0
# 3      3.0        0.0        135.0   23.8712    91.3602           2.0
# 4      4.0        1.0       1800.0   21.9603    82.4091           1.0
# ..     ...        ...          ...       ...        ...           ...
# 902  902.0      491.0       1600.0   16.2949    77.3568           1.0
# 903  903.0      822.0          3.0   12.8932    78.1654           6.0
# 904  904.0      891.0         25.5   15.2758    75.5811           7.0
# 905  905.0      539.0         80.0   24.3500    73.7477           1.0
# 906  906.0      876.0         16.5    9.9344    77.4768           7.0
#
#      other_fuel1  commissioning_year  owner  source    url  \
# 0            2.0         2011.000000  229.0   109.0  128.0
# ...

# %% [markdown]
# ### Correlations:

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df.describe(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
#Correlation matrix
df.corr()
# Out:
#                          name  gppd_idnr  capacity_mw  latitude  longitude  \
# name                 1.000000   0.332205     0.060240 -0.135247   0.020279
# gppd_idnr            0.332205   1.000000    -0.335742 -0.105728  -0.377812
# capacity_mw          0.060240  -0.335742     1.000000  0.050984   0.195882
# latitude            -0.135247  -0.105728     0.050984  1.000000   0.036362
# longitude            0.020279  -0.377812     0.195882  0.036362   1.000000
# primary_fuel         0.040753   0.609180    -0.380395 -0.010204  -0.347948
# other_fuel1         -0.074663   0.002333     0.003105  0.036695   0.030311
# commissioning_year  -0.043569   0.044059     0.274292  0.102069   0.092331
# owner                0.098075   0.630589    -0.311048 -0.071182  -0.301285
# source              -0.014640   0.416384    -0.242122  0.055927  -0.239333
# url                  0.041917   0.597080    -0.243830 -0.131038  -0.302985
# ...

# %%
#Correlation of Columns with target column using heatmap
plt.figure(figsize = (25,25))
sns.heatmap(df.corr(),annot = True, linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here we can see high correlations at bottom right of heatmap

# %% [markdown]
# ### Checking columns which appear to be highly correlated with target columns (capacity_mw)

# %%
plt.figure(figsize=(22,7))
df.corr()['capacity_mw'].sort_values(ascending = False).drop(['capacity_mw']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('capacity_mw',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# #### Here we can see high correlations

# %% [markdown]
# ### Checking columns which appear to be highly correlated with target columns (primary_fuel)

# %%
plt.figure(figsize=(22,7))
df.corr()['primary_fuel'].sort_values(ascending = False).drop(['primary_fuel']).plot(kind='bar',fontsize=14)
plt.xlabel('Feature',fontsize=14)
plt.ylabel('primary_fuel',fontsize=14)
plt.title('Correlation',fontsize=20)
plt.show()

# %% [markdown]
# #### Here we can see good correlations but not very high correlations

# %%
#Checking correlation between capacity_mw and generation_gwh_2018
plt.figure(figsize=(22,7))
plt.scatter(df.capacity_mw,df.generation_gwh_2018)
plt.show()

# %% [markdown]
# #### We can see very good correlations

# %%
#Checking correlation between generation_gwh_2014 and generation_gwh_2015
plt.figure(figsize=(22,7))
plt.scatter(df.generation_gwh_2014,df.generation_gwh_2015)
plt.show()

# %% [markdown]
# #### We can see very high correlations

# %%
#Checking correlation between generation_gwh_2016 and generation_gwh_2015
plt.figure(figsize=(22,7))
plt.scatter(df.generation_gwh_2016,df.generation_gwh_2015)
plt.show()

# %% [markdown]
# #### We can see very high correlations

# %%
#Checking correlation between generation_gwh_2016 and generation_gwh_2017
plt.figure(figsize=(22,7))
plt.scatter(df.generation_gwh_2016,df.generation_gwh_2017)
plt.show()

# %% [markdown]
# #### We can see very high correlations

# %%
#Checking correlation between generation_gwh_2018 and generation_gwh_2017
plt.figure(figsize=(22,7))
plt.scatter(df.generation_gwh_2018,df.generation_gwh_2017)
plt.show()

# %% [markdown]
# #### We can see very high correlations

# %% [markdown]
# ### Checkin VIF for confirmation of above conclusion:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X1 = df[['capacity_mw','generation_gwh_2018']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X1.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X1.values, i)
                          for i in range(len(X1.columns))]

# %%
print(vif_dF)
# Out:
#                feature       VIF
# 0          capacity_mw  3.194246
# 1  generation_gwh_2018  3.194246

# %% [markdown]
# ### As we can see there is low correlation

# %%
X2 = df[['generation_gwh_2014','generation_gwh_2015']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X2.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X2.values, i)
                          for i in range(len(X2.columns))]

# %%
print(vif_dF)
# Out:
#                feature        VIF
# 0  generation_gwh_2014  18.944726
# 1  generation_gwh_2015  18.944726

# %% [markdown]
# ### As we can see here correlation is low (< 10)

# %%
X1 = df[['generation_gwh_2016','generation_gwh_2015']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X1.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X1.values, i)
                          for i in range(len(X1.columns))]

# %%
print(vif_dF)
# Out:
#                feature        VIF
# 0  generation_gwh_2016  28.021999
# 1  generation_gwh_2015  28.021999

# %% [markdown]
# ### As we can see there is high correlations (>10)

# %%
X2 = df[['generation_gwh_2016','generation_gwh_2017']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X2.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X2.values, i)
                          for i in range(len(X2.columns))]

# %%
print(vif_dF)
# Out:
#                feature        VIF
# 0  generation_gwh_2016  24.944071
# 1  generation_gwh_2017  24.944071

# %%
X2 = df[['generation_gwh_2018','generation_gwh_2017']]

# VIF dataframe
vif_dF = pd.DataFrame()
vif_dF["feature"] = X2.columns
  
# calculating VIF for each feature
vif_dF["VIF"] = [variance_inflation_factor(X2.values, i)
                          for i in range(len(X2.columns))]

# %%
print(vif_dF)
# Out:
#                feature        VIF
# 0  generation_gwh_2018  50.612114
# 1  generation_gwh_2017  50.612114

# %% [markdown]
# ### As we can see here correlation is high(> 10)

# %% [markdown]
# ### Here due to high correlations we need to drop some columns

# %%
df.drop('generation_gwh_2016', axis=1, inplace=True)
df.drop('generation_gwh_2017', axis=1, inplace=True)
df.drop('generation_gwh_2018', axis=1, inplace=True)

# %% [markdown]
# ### Removing Skewness :

# %%
#Checking skewness
df.skew()
# Out:
# name                    0.000000
# gppd_idnr               0.000000
# capacity_mw             3.123576
# latitude               -0.149698
# longitude               1.141881
# primary_fuel            0.472251
# other_fuel1           -20.453120
# commissioning_year     -1.399359
# owner                   1.364406
# source                  1.827373
# url                     1.510537
# geolocation_source     -2.159841
# generation_gwh_2014     5.035446
# generation_gwh_2015     5.364134
# dtype: float64

# %% [markdown]
# #### Acceptable skewness (-0.65,+0.65)

# %%
from scipy.stats import yeojohnson
df.longitude = yeojohnson(df.longitude)[0]
df.generation_gwh_2014 = yeojohnson(df.generation_gwh_2014)[0]
df.generation_gwh_2015 = yeojohnson(df.generation_gwh_2015)[0]

# %%
#Checking skewness
df.skew()
# Out:
# name                    0.000000
# gppd_idnr               0.000000
# capacity_mw             3.123576
# latitude               -0.149698
# longitude               0.000000
# primary_fuel            0.472251
# other_fuel1           -20.453120
# commissioning_year     -1.399359
# owner                   1.364406
# source                  1.827373
# url                     1.510537
# geolocation_source     -2.159841
# generation_gwh_2014     0.123226
# generation_gwh_2015     0.074582
# dtype: float64

# %% [markdown]
# #### Now all continous columns are in acceptable skew range

# %% [markdown]
# ### Removing outliers :

# %%
#Outlier check
df.dtypes
# Out:
# name                   float64
# gppd_idnr              float64
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel           float64
# other_fuel1            float64
# commissioning_year     float64
# owner                  float64
# source                 float64
# url                    float64
# geolocation_source     float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# dtype: object

# %%
#Checking only for continous data types
df.plot.box(layout =(6,8),subplots=True,figsize=(16,20))
# Out:
# name                      AxesSubplot(0.125,0.772143;0.0824468x0.107857)
# gppd_idnr              AxesSubplot(0.223936,0.772143;0.0824468x0.107857)
# capacity_mw            AxesSubplot(0.322872,0.772143;0.0824468x0.107857)
# latitude               AxesSubplot(0.421809,0.772143;0.0824468x0.107857)
# longitude              AxesSubplot(0.520745,0.772143;0.0824468x0.107857)
# primary_fuel           AxesSubplot(0.619681,0.772143;0.0824468x0.107857)
# other_fuel1            AxesSubplot(0.718617,0.772143;0.0824468x0.107857)
# commissioning_year     AxesSubplot(0.817553,0.772143;0.0824468x0.107857)
# owner                     AxesSubplot(0.125,0.642714;0.0824468x0.107857)
# source                 AxesSubplot(0.223936,0.642714;0.0824468x0.107857)
# url                    AxesSubplot(0.322872,0.642714;0.0824468x0.107857)
# geolocation_source     AxesSubplot(0.421809,0.642714;0.0824468x0.107857)
# generation_gwh_2014    AxesSubplot(0.520745,0.642714;0.0824468x0.107857)
# ...

# %% [markdown]
# ### There looks like outliers in some columns so now we check with z-score:

# %%
#Outlier removal using z-score
df.shape
# Out:
# (907, 14)

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
threshhold = 3
np.where(z>3)
# Out:
# (array([ 15,  71,  80, 143, 147, 191, 209, 222, 299, 308, 308, 321, 342,
#         345, 363, 364, 364, 364, 371, 375, 444, 454, 478, 482, 484, 493,
#         493, 493, 494, 494, 494, 538, 541, 573, 583, 592, 601, 621, 648,
#         648, 648, 657, 657, 657, 661, 669, 689, 695, 695, 695, 706, 709,
#         721, 726, 726, 726, 728, 767, 786, 786, 786, 788, 807, 808, 808,
#         808, 811, 813, 817, 832, 848, 870, 871, 879, 880, 880, 880, 895,
#         900]),
#  array([ 2,  9,  9,  2,  2,  9,  2,  7,  9,  2, 12,  9,  7,  9,  2,  2, 12,
#         13,  7,  2,  7,  7,  7,  2,  7,  2, 12, 13,  2, 12, 13,  7,  7,  7,
#          7,  7,  7,  7,  2, 12, 13,  2, 12, 13,  9,  9,  9,  2, 12, 13,  7,
#          7, 12,  2, 12, 13,  7,  2,  2, 12, 13,  2,  7,  2, 12, 13,  6,  6,
#          6,  9,  7,  9,  9,  9,  2, 12, 13,  9,  9]))

# %%
df_new_z = df[(z<3).all(axis = 1)]
df_new_z
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  \
# 0      0.0      657.0          2.5   28.1839   0.203878           6.0
# 1      1.0      519.0         98.0   24.7663   0.203878           1.0
# 2      2.0      853.0         39.2   21.9038   0.203878           7.0
# 3      3.0        0.0        135.0   23.8712   0.203878           2.0
# 4      4.0        1.0       1800.0   21.9603   0.203878           1.0
# ..     ...        ...          ...       ...        ...           ...
# 902  902.0      491.0       1600.0   16.2949   0.203878           1.0
# 903  903.0      822.0          3.0   12.8932   0.203878           6.0
# 904  904.0      891.0         25.5   15.2758   0.203878           7.0
# 905  905.0      539.0         80.0   24.3500   0.203878           1.0
# 906  906.0      876.0         16.5    9.9344   0.203878           7.0
#
#      other_fuel1  commissioning_year  owner  source    url  \
# 0            2.0         2011.000000  229.0   109.0  128.0
# ...

# %%
df_new_z.shape
# Out:
# (849, 14)

# %%
#Data Loss
Data_loss = (907-849)/907*100
Data_loss
# Out:
# 6.39470782800441

# %% [markdown]
# #### As we can see outliers have been removed

# %% [markdown]
# ## Separating the columns into features and target (primary_fuel):

# %%
feature = df_new_z.drop("primary_fuel",axis=1)
target = df_new_z["primary_fuel"]

# %% [markdown]
# ### Upsampling to remove Imbalance classification of target variable (primary_fuel):

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

print(Counter(target))

# Using oversampling
oversample = SMOTE()

feature_over, target_over = oversample.fit_resample(feature, target)

print(Counter(target_over))
# Out:
# Counter({1.0: 232, 3.0: 232, 7.0: 123, 6.0: 122, 2.0: 68, 0.0: 45, 5.0: 18, 4.0: 9})
# Counter({6.0: 232, 1.0: 232, 7.0: 232, 2.0: 232, 3.0: 232, 0.0: 232, 5.0: 232, 4.0: 232})

# %% [markdown]
# ### Model 1:

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()


from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(accuracy_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(accuracy_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.6940700808625337
# At random state 0 the testing accuracy is : 0.6854838709677419
#
#
# At random state 1 the training accuracy is : 0.6880053908355795
# At random state 1 the testing accuracy is : 0.6989247311827957
#
#
# At random state 2 the training accuracy is : 0.6792452830188679
# At random state 2 the testing accuracy is : 0.6908602150537635
#
#
# At random state 3 the training accuracy is : 0.683288409703504
# At random state 3 the testing accuracy is : 0.6317204301075269
#
#
# At random state 4 the training accuracy is : 0.6758760107816711
# At random state 4 the testing accuracy is : 0.6290322580645161
#
#
# At random state 5 the training accuracy is : 0.6725067385444744
# At random state 5 the testing accuracy is : 0.717741935483871
#
#
# At random state 6 the training accuracy is : 0.6913746630727763
# At random state 6 the testing accuracy is : 0.696236559139785
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(feature_over,target_over,test_size = 0.2,random_state = 0)

# %%
lr.fit(features_train,target_train)
# Out:
# LogisticRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(accuracy_score(target_test,pred_test))
# Out:
# 0.6854838709677419

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print("Confusion matrix for model : \n",confusion_matrix(target_test,pred_test))
print("Classification Report for train data : \n",classification_report(target_train,pred_train))
print("Classification Report for test data : \n",classification_report(target_test,pred_test))
# Out:
# Confusion matrix for model :
#  [[51  3  0  0  0  5  0  0]
#  [ 8  6  5 11  6  6  0  1]
#  [ 1  2 17 11  1  7  0  0]
#  [ 0  4  6 32  3  9  0  0]
#  [ 0  5  0  4 38  0  0  0]
#  [11  0  2  2  0 25  0  0]
#  [ 0  1  0  0  0  0 47  3]
#  [ 0  0  0  0  0  0  0 39]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.17      0.21      0.19       173
#          1.0       0.13      0.07      0.09       189
#          2.0       0.16      0.10      0.12       193
#          3.0       0.17      0.21      0.19       178
#          4.0       0.13      0.15      0.14       185
#          5.0       0.11      0.13      0.12       192
#          6.0       0.15      0.15      0.15       181
#          7.0       0.11      0.11      0.11       193
#
#     accuracy                           0.14      1484
#    macro avg       0.14      0.14      0.14      1484
# weighted avg       0.14      0.14      0.14      1484
#
# ...

# %% [markdown]
# ### Cross Validation of model:

# %%
Train_accuracy = accuracy_score(target_train,pred_train)
Test_accuracy = accuracy_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature_over,target_over,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.6023706896551724 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# At cross fold 3 the cv score is 0.6384675843872482 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# At cross fold 4 the cv score is 0.650323275862069 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# At cross fold 5 the cv score is 0.6546488711126568 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# At cross fold 6 the cv score is 0.6616748442774124 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# At cross fold 7 the cv score is 0.6562592464989968 and accuracy score for training is 0.1408355795148248 and accuracy score for testing is 0.6854838709677419
#
#
# ...

# %% [markdown]
# ### Trying other models:

# %%
def model_selection(algorithm_instance,features_train,target_train,features_test,target_test):
    algorithm_instance.fit(features_train,target_train)
    model_1_pred_train = algorithm_instance.predict(features_train)
    model_1_pred_test = algorithm_instance.predict(features_test)
    print("Accuracy for the training model : ",accuracy_score(target_train,model_1_pred_train))
    print("Accuracy for the testing model : ",accuracy_score(target_test,model_1_pred_test))
    print("Confusion matrix for model : \n",confusion_matrix(target_test,model_1_pred_test))
    print("Classification Report for train data : \n",classification_report(target_train,model_1_pred_train))
    print("Classification Report for test data : \n",classification_report(target_test,model_1_pred_test))
    
    Train_accuracy = accuracy_score(target_train,model_1_pred_train)
    Test_accuracy = accuracy_score(target_test,model_1_pred_test)
    
    for j in range(2,10):
        cv_score = cross_val_score(algorithm_instance,feature_over,target_over,cv=j)
        cv_mean = cv_score.mean()
        print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
        print("\n")

# %% [markdown]
# ### Model 2:

# %%
from sklearn.neighbors import KNeighborsClassifier
model_selection(KNeighborsClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.8349056603773585
# Accuracy for the testing model :  0.7419354838709677
# Confusion matrix for model :
#  [[55  0  1  0  0  3  0  0]
#  [12  9  9  4  4  4  0  1]
#  [ 0  3 27  1  2  6  0  0]
#  [ 0  4 14 26  2  8  0  0]
#  [ 0  3  2  0 42  0  0  0]
#  [ 7  1  2  1  0 29  0  0]
#  [ 0  1  0  0  0  1 49  0]
#  [ 0  0  0  0  0  0  0 39]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.98      0.90       173
#          1.0       0.72      0.50      0.59       189
#          2.0       0.73      0.81      0.76       193
#          3.0       0.79      0.63      0.70       178
#          4.0       0.81      0.88      0.84       185
#          5.0       0.80      0.91      0.85       192
#          6.0       1.00      0.97      0.99       181
#          7.0       0.98      1.00      0.99       193
#
#     accuracy                           0.83      1484
# ...

# %% [markdown]
# ### Model 3:

# %%
from sklearn.tree import DecisionTreeClassifier
model_selection(DecisionTreeClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  1.0
# Accuracy for the testing model :  0.8387096774193549
# Confusion matrix for model :
#  [[55  2  2  0  0  0  0  0]
#  [ 5 19  7  8  4  0  0  0]
#  [ 0  4 32  2  0  1  0  0]
#  [ 0  5  9 35  1  4  0  0]
#  [ 0  0  0  0 47  0  0  0]
#  [ 1  0  3  2  0 34  0  0]
#  [ 0  0  0  0  0  0 51  0]
#  [ 0  0  0  0  0  0  0 39]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       173
#          1.0       1.00      1.00      1.00       189
#          2.0       1.00      1.00      1.00       193
#          3.0       1.00      1.00      1.00       178
#          4.0       1.00      1.00      1.00       185
#          5.0       1.00      1.00      1.00       192
#          6.0       1.00      1.00      1.00       181
#          7.0       1.00      1.00      1.00       193
#
#     accuracy                           1.00      1484
# ...

# %% [markdown]
# ### Model 4:

# %%
from sklearn.ensemble import RandomForestClassifier
model_selection(RandomForestClassifier(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  1.0
# Accuracy for the testing model :  0.8844086021505376
# Confusion matrix for model :
#  [[58  1  0  0  0  0  0  0]
#  [ 5 24  6  3  5  0  0  0]
#  [ 0  3 33  1  0  2  0  0]
#  [ 0  4 11 37  1  1  0  0]
#  [ 0  0  0  0 47  0  0  0]
#  [ 0  0  0  0  0 40  0  0]
#  [ 0  0  0  0  0  0 51  0]
#  [ 0  0  0  0  0  0  0 39]]
# Classification Report for train data :
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       173
#          1.0       1.00      1.00      1.00       189
#          2.0       1.00      1.00      1.00       193
#          3.0       1.00      1.00      1.00       178
#          4.0       1.00      1.00      1.00       185
#          5.0       1.00      1.00      1.00       192
#          6.0       1.00      1.00      1.00       181
#          7.0       1.00      1.00      1.00       193
#
#     accuracy                           1.00      1484
# ...

# %% [markdown]
# ### Conclusion: Here RandomForestClassifier() gives best accuracy hence taking it as main model

# %% [markdown]
# ### Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV

#using 4 parameters
parameters = {'criterion':['entropy','gini'], 'max_features': ["auto","sqrt","log2"], 'min_samples_split' : [2,5,10], 'max_depth':[2,3,5]}
rf = RandomForestClassifier()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2}

# %%
rf = RandomForestClassifier(criterion = "entropy", max_features = "log2", max_depth = 5, min_samples_split = 2)
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = accuracy_score(target_test,pred_decision)
print('Accuracy score: ', abs(rfs)*100)

rfscore = cross_val_score(rf,feature,target,cv=6)
rfc =rfscore.mean()
rfc
print('Cross Validation score: ', abs(rfc)*100)
# Out:
# Accuracy score:  78.49462365591397
# Cross Validation score:  79.38684114141111

# %% [markdown]
# ### Conclusion : We got Accuracy score as 78.49% for primary_fuel (by multiclass Classifier model)

# %% [markdown]
# ## Separating the columns into features and target (capacity_mw):

# %%
feature = df_new_z.drop("capacity_mw",axis=1)
target = df_new_z["capacity_mw"]

# %% [markdown]
# ### Model 1:

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()


from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(r2_score(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(r2_score(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 0.506795429040713
# At random state 0 the testing accuracy is : 0.34068641261996735
#
#
# At random state 1 the training accuracy is : 0.46251066042750866
# At random state 1 the testing accuracy is : 0.5604942529291317
#
#
# At random state 2 the training accuracy is : 0.5009822156713044
# At random state 2 the testing accuracy is : 0.4064787183174582
#
#
# At random state 3 the training accuracy is : 0.4937637717021902
# At random state 3 the testing accuracy is : 0.4298343462847215
#
#
# At random state 4 the training accuracy is : 0.4863081195848282
# At random state 4 the testing accuracy is : 0.4579742236473252
#
#
# At random state 5 the training accuracy is : 0.4917392827650716
# At random state 5 the testing accuracy is : 0.3905850997189825
#
#
# At random state 6 the training accuracy is : 0.4736112148876185
# At random state 6 the testing accuracy is : 0.5059040082614097
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = 4)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.4579742236473252

# %% [markdown]
# ### Cross Validation of model:

# %%
Train_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,feature,target,cv=j)
    cv_mean = cv_score.mean()
    print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.35553454891286274 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# At cross fold 3 the cv score is 0.4465795704418268 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# At cross fold 4 the cv score is 0.43301622316794924 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# At cross fold 5 the cv score is 0.457021521678035 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# At cross fold 6 the cv score is 0.45493681570086436 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# At cross fold 7 the cv score is 0.4504778222160816 and accuracy score for training is -0.5499971353883633 and accuracy score for testing is 0.4579742236473252
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual capacity')
plt.ylabel('Predicted capacity')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# #### We can see above not many points lie on or around best fit curve

# %% [markdown]
# ### Trying other models:

# %%
def model_selection(algorithm_instance,features_train,target_train,features_test,target_test):
    algorithm_instance.fit(features_train,target_train)
    model_1_pred_train = algorithm_instance.predict(features_train)
    model_1_pred_test = algorithm_instance.predict(features_test)
    print("Accuracy for the training model : ",r2_score(target_train,model_1_pred_train))
    print("Accuracy for the testing model : ",r2_score(target_test,model_1_pred_test))
    
    Train_accuracy = r2_score(target_train,model_1_pred_train)
    Test_accuracy = r2_score(target_test,model_1_pred_test)
    
    for j in range(2,10):
        cv_score = cross_val_score(algorithm_instance,feature,target,cv=j)
        cv_mean = cv_score.mean()
        print("At cross fold " + str(j) + " the cv score is " + str(cv_mean) + " and accuracy score for training is " + str(Train_accuracy) + " and accuracy score for testing is " + str(Test_accuracy))
        print("\n")

# %% [markdown]
# ### Model 2:

# %%
import xgboost as xgb
model_selection(xgb.XGBRegressor(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.9997492583878532
# Accuracy for the testing model :  0.6357896243412922
# At cross fold 2 the cv score is 0.6209464463105595 and accuracy score for training is 0.9997492583878532 and accuracy score for testing is 0.6357896243412922
#
#
# At cross fold 3 the cv score is 0.4854378473348106 and accuracy score for training is 0.9997492583878532 and accuracy score for testing is 0.6357896243412922
#
#
# At cross fold 4 the cv score is 0.6934895945200299 and accuracy score for training is 0.9997492583878532 and accuracy score for testing is 0.6357896243412922
#
#
# At cross fold 5 the cv score is 0.6377499927816396 and accuracy score for training is 0.9997492583878532 and accuracy score for testing is 0.6357896243412922
#
#
# At cross fold 6 the cv score is 0.6380569320106778 and accuracy score for training is 0.9997492583878532 and accuracy score for testing is 0.6357896243412922
#
#
# ...

# %% [markdown]
# ### Model 3:

# %%
from sklearn.ensemble import RandomForestRegressor
model_selection(RandomForestRegressor(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  0.9639305424457788
# Accuracy for the testing model :  0.6346405581970196
# At cross fold 2 the cv score is 0.6599274529729964 and accuracy score for training is 0.9639305424457788 and accuracy score for testing is 0.6346405581970196
#
#
# At cross fold 3 the cv score is 0.7018890143253224 and accuracy score for training is 0.9639305424457788 and accuracy score for testing is 0.6346405581970196
#
#
# At cross fold 4 the cv score is 0.7084230234261195 and accuracy score for training is 0.9639305424457788 and accuracy score for testing is 0.6346405581970196
#
#
# At cross fold 5 the cv score is 0.7234126211326044 and accuracy score for training is 0.9639305424457788 and accuracy score for testing is 0.6346405581970196
#
#
# At cross fold 6 the cv score is 0.7256179509872916 and accuracy score for training is 0.9639305424457788 and accuracy score for testing is 0.6346405581970196
#
#
# ...

# %% [markdown]
# ### Model 4:

# %%
from sklearn.svm import SVR
model_selection(SVR(),features_train,target_train,features_test,target_test)
# Out:
# Accuracy for the training model :  -0.22613233705404512
# Accuracy for the testing model :  -0.23016786023717817
# At cross fold 2 the cv score is -0.24149694352274986 and accuracy score for training is -0.22613233705404512 and accuracy score for testing is -0.23016786023717817
#
#
# At cross fold 3 the cv score is -0.23254766326292087 and accuracy score for training is -0.22613233705404512 and accuracy score for testing is -0.23016786023717817
#
#
# At cross fold 4 the cv score is -0.23022434818900583 and accuracy score for training is -0.22613233705404512 and accuracy score for testing is -0.23016786023717817
#
#
# At cross fold 5 the cv score is -0.23129443775015074 and accuracy score for training is -0.22613233705404512 and accuracy score for testing is -0.23016786023717817
#
#
# At cross fold 6 the cv score is -0.23144991665095158 and accuracy score for training is -0.22613233705404512 and accuracy score for testing is -0.23016786023717817
#
#
# ...

# %% [markdown]
# ### Conclusion: Here RandomForestRegressor() gives best accuracy hence taking it as main model

# %% [markdown]
# ### Below we have tested mean squared error, Root mean squared error and Mean Absolute error method also:

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
# Mean Squared Error Method
x = RandomForestRegressor()
for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_squared_error(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_squared_error(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 7510.223061662405
# At random state 0 the testing accuracy is : 64480.97397918616
#
#
# At random state 1 the training accuracy is : 6896.7987962704765
# At random state 1 the testing accuracy is : 48726.1933721857
#
#
# At random state 2 the training accuracy is : 6238.818695271738
# At random state 2 the testing accuracy is : 66478.99430009206
#
#
# At random state 3 the training accuracy is : 6238.538888700929
# At random state 3 the testing accuracy is : 63165.98130181561
#
#
# At random state 4 the training accuracy is : 6269.792737651611
# At random state 4 the testing accuracy is : 74673.29516215397
#
#
# At random state 5 the training accuracy is : 6880.22545232953
# At random state 5 the testing accuracy is : 47525.016666982985
#
#
# At random state 6 the training accuracy is : 6165.024426723098
# At random state 6 the testing accuracy is : 59657.77486425739
#
#
# At random state 7 the training accuracy is : 6107.130948972396
# ...

# %%
# Root Mean Squared Error Method

for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_squared_error(target_train,pred_train,squared=False)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_squared_error(target_test,pred_test,squared=False)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 82.4760468362704
# At random state 0 the testing accuracy is : 257.09259833002164
#
#
# At random state 1 the training accuracy is : 85.8523999004728
# At random state 1 the testing accuracy is : 219.08119440227964
#
#
# At random state 2 the training accuracy is : 80.84580837935518
# At random state 2 the testing accuracy is : 258.9440987041395
#
#
# At random state 3 the training accuracy is : 80.17071772434875
# At random state 3 the testing accuracy is : 247.1698497426583
#
#
# At random state 4 the training accuracy is : 78.50301184118132
# At random state 4 the testing accuracy is : 273.6034539730421
#
#
# At random state 5 the training accuracy is : 88.51624049941293
# At random state 5 the testing accuracy is : 215.69324635333177
#
#
# At random state 6 the training accuracy is : 81.76407253374586
# At random state 6 the testing accuracy is : 237.3994535304743
#
#
# At random state 7 the training accuracy is : 78.96873364247786
# ...

# %%
# Mean Absolute Error Method

for i in range(0,10):
    features_train,features_test,target_train,target_test = train_test_split(feature,target,test_size = 0.2,random_state = i)
    x.fit(features_train,target_train)
    pred_train = x.predict(features_train)
    pred_test = x.predict(features_test)
    print("At random state " + str(i) + " the training accuracy is : " + str(mean_absolute_error(target_train,pred_train)))
    print("At random state " + str(i) + " the testing accuracy is : " + str(mean_absolute_error(target_test,pred_test)))
    print("\n")
# Out:
# At random state 0 the training accuracy is : 43.37380064801178
# At random state 0 the testing accuracy is : 131.78996441176471
#
#
# At random state 1 the training accuracy is : 40.96053126656849
# At random state 1 the testing accuracy is : 116.27486805882354
#
#
# At random state 2 the training accuracy is : 41.963718379970544
# At random state 2 the testing accuracy is : 123.44542870588236
#
#
# At random state 3 the training accuracy is : 42.31828020618557
# At random state 3 the testing accuracy is : 121.6373314117647
#
#
# At random state 4 the training accuracy is : 39.75704103092783
# At random state 4 the testing accuracy is : 124.83059370588235
#
#
# At random state 5 the training accuracy is : 45.99165147275405
# At random state 5 the testing accuracy is : 104.17556711764705
#
#
# At random state 6 the training accuracy is : 42.30089762886598
# At random state 6 the testing accuracy is : 124.84168852941177
#
#
# ...

# %% [markdown]
# #### Conclusion of 4 metrics method : As we can see we got best accuracy reseults in r2_score among (r2_score, mse, rms,mae)

# %% [markdown]
# ### Regularization using Lasso:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls = Lasso(alpha = 1, random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.2796758992024593

# %%
cv_score = cross_val_score(ls,feature,target,cv=6)
cv_mean =cv_score.mean()
abs(cv_mean)
# Out:
# 0.45706822563843685

# %% [markdown]
# ### Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

#using 4 parameters
parameters = {'criterion':['mse','mae'], 'max_features': ["auto","sqrt","log2"], 'min_samples_split' : [2,5,10], 'min_samples_leaf' : [1,2,4]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}

# %%
rf = RandomForestRegressor(criterion = "mse", max_features = "auto", min_samples_leaf = 4, min_samples_split = 5)
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 score: ', abs(rfs)*100)

rfscore = cross_val_score(ls,feature,target,cv=6)
rfc =rfscore.mean()
rfc
print('Cross Validation score: ', abs(rfc)*100)
# Out:
# R2 score:  57.253211192187315
# Cross Validation score:  45.70682256384369

# %% [markdown]
# ### Conclusion : We got Accuracy score as 57.25% for capacity_mw
